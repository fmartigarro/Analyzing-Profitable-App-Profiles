# %% [markdown]
# # Profitable App Profiles for the App Store and Google Play Markets

# %% [markdown]
# Imagine that I am working as a data analyst for a company that only builds mobile apps that are free to download and install. Our main source of revenue consists of in-app adds, which means that our revenue for any given app is mostly influenced by the number of users that use our app. Our goal for this project is to analyze data to help our developers understand what kinds of apps are likely to attract more users.
#
# The purpose of this project is to find mobile app profiles that are profitable for the App Store and Google Play markets. This project replicates challenges that a data analyst regularly encounters in their work.
#
# ---

# %% [markdown]
# ## Opening and Exploring the Data

# %% [markdown]
# As of June 2019, there were approximately 2.2 million apps available for download on the App Store, and approximately 2.8 million apps available for download on the Google Play Store.
#
# Collecting data for ~5 million apps is extremely time consuming and costly, so for the purposes of this project we will analyze sample data instead. Here are two data sets that we will use for our analyses. You can access and download them through the link below:
# - Google Play data set containing approximately ten thousand Android apps: [Google Play Store Dataset](https://www.kaggle.com/lava18/google-play-store-apps)
# - App Store data set containing approximately seven thousand iOS apps: [App Store Dataset](https://www.kaggle.com/ramamet4/app-store-apple-data-set-10k-apps)

# %%
from csv import reader 

#Opening and reading data from the google play store, storing data in variables a_header and a_body
opened_file = open('googleplaystore.csv')
read_file = reader(opened_file)
android = list(read_file)
a_header = android[0]
a_body = android[1:]

#opening and reading data from the ios store, storing the header and body data
opened_file = open('AppleStore.csv')
read_file = reader(opened_file)
ios = list(read_file)
ios_header = ios[0]
ios_body = ios[1:]

# %%
#exploring the first 3 rows of each dataset
def explore_data(dataset, start, end):
    data = dataset[start:end]
    for element in data:
        print('\n', element)

explore_data(a_body, 0, 3)
print('\n')
explore_data(ios_body, 0 , 3)
# Out:
#  ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#  ['Coloring book moana', 'ART_AND_DESIGN', '3.9', '967', '14M', '500,000+', 'Free', '0', 'Everyone', 'Art & Design;Pretend Play', 'January 15, 2018', '2.0.0', '4.0.3 and up']
#
#  ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
#
#  ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']
#
#  ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1']
#
#  ['529479190', 'Clash of Clans', '116476928', 'USD', '0.0', '2130805', '579', '4.5', '4.5', '9.24.12', '9+', 'Games', '38', '5', '18', '1']

# %% [markdown]
# The first three rows are outputs from the Google Play dataset. The following three rows are outputs from the App Store dataset. To see how many rows and columns are in each dataset, we can define a function below that provides this result:

# %%
#defining a function that prints the rows and columns of a given dataset
def data_info(name, dataset):
    columns = len(dataset[0])
    rows = len(dataset)
    print("\nNumber of rows in ", name, "data set: ", rows)
    print("Number of columns in ", name, "data set: ", columns)

data_info("Android", a_body)
data_info("iOS", ios_body)
# Out:
# Number of rows in  Android data set:  10841
# Number of columns in  Android data set:  13
#
# Number of rows in  IOS data set:  7197
# Number of columns in  IOS data set:  16

# %% [markdown]
# This output shows that the amount of in the Android data set is about 50.6% larger than the iOS data set, and the iOS data set contains 3 more columns per entry. Before making any kind of analysis, however, we need to check that the data is clean.

# %% [markdown]
# ## Cleaning the Data

# %% [markdown]
# The Google Play data set has a dedicated discussion section, and we can see that one of the discussions outlines an error for row 10472. By printing out this row, we can see that the error is attributed to a null value within the row, as depicted by '' in the ninth column. If we didn't know that there was an error in row 10472, however, we could find missing entries within our data manually:

# %%
#manually figuring out where our data contains null values
def check_null(dataset):
    error_list = {}
    
    for app in dataset:
        name = dataset[0]
        for i in range(len(name) - 1):
            null = ''
            column = app[i]
            
            if (column == null): 
                error_list[app[0]] = dataset.index(app)

    print("")
    return error_list

null_values = check_null(a_body)
print(null_values)
print("\n")

#printing rows with errors and verifying that we see null values
print(a_body[10472])
print("")
print(a_body[1553])
# Out:
# {'Life Made WI-Fi Touchscreen Photo Frame': 10472, 'Market Update Helper': 1553}
#
#
# ['Life Made WI-Fi Touchscreen Photo Frame', '1.9', '19', '3.0M', '1,000+', 'Free', '0', 'Everyone', '', 'February 11, 2018', '1.0.19', '4.0 and up']
#
# ['Market Update Helper', 'LIBRARIES_AND_DEMO', '4.1', '20145', '11k', '1,000,000+', 'Free', '0', 'Everyone', 'Libraries & Demo', 'February 12, 2013', '', '1.5 and up']

# %% [markdown]
# Manually, we have found rows which contain a null value ( '' ) within their columns. This includes row #10472 and a new, unkowingly erroneus row: #1553 . Row #10472 also contains another error: it has a listed rating of 19. This is clearly incorrect because the maximum rating for a Google Play app is 5.
#
# We can remove these entries from our dataset by using the del keyword:

# %%
#cleaning the data by removing the rows with incomplete data
del a_body[10472]
del a_body[1553]

## DO NOT RUN AGAIN

# %% [markdown]
# ## Removing Duplicate Entries

# %% [markdown]
# If we look closely at the Google Play data set, we'll eventually find that some apps in this play store have more than one entry. In order to make this data cleaner, we need to remove these duplicate entries.

# %%
#for example, lets see how many duplicate entries there are of 'Instagram'
for app in a_body:
    if app[0] == 'Instagram':
        print(app, "\n")
# Out:
# ['Instagram', 'SOCIAL', '4.5', '66577313', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
#
# ['Instagram', 'SOCIAL', '4.5', '66577446', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
#
# ['Instagram', 'SOCIAL', '4.5', '66577313', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
#
# ['Instagram', 'SOCIAL', '4.5', '66509917', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']

# %%
#lets start by sorting the apps into a duplicate and unique list and finding how many apps are in each one
unique_apps = []
duplicate_apps = []

for element in a_body:
    name = element[0]
    if name in unique_apps:
        duplicate_apps.append(name)
    else:
        unique_apps.append(name)
        
print("Number of unique apps: ", len(unique_apps))
print("Number of duplicate apps: ", len(duplicate_apps), "\n")
print("Examples of duplicate apps: ", duplicate_apps[:15])

## we can see that in the range of duplicate apps, 'Box' and 'Google My Business' have already printed more than once
# Out:
# Number of unique apps:  9658
# Number of duplicate apps:  1181
#
# Examples of duplicate apps:  ['Quick PDF Scanner + OCR FREE', 'Box', 'Google My Business', 'ZOOM Cloud Meetings', 'join.me - Simple Meetings', 'Box', 'Zenefits', 'Google Ads', 'Google My Business', 'Slack', 'FreshBooks Classic', 'Insightly CRM', 'QuickBooks Accounting: Invoicing & Expenses', 'HipChat - Chat Built for Teams', 'Xero Accounting Software']

# %% [markdown]
# We don't want to count certain apps more than once when we analyze data, so we need to remove the duplicate entries and keep only one entry per app.
#
# Instead of removing duplicate rows randomly, it would be better to analyze the differences between these duplicate entries and determine a criteria in order to keep the most relevant and reliable ones.
#
# If you look at the duplicate entries above for the Instagram app, the main difference between the entries corresponds to the number of reviews. Ideally, we should keep the entry with the greatest number of reviews because the more reviews an app gets, the more reliable the rating is.

# %%
#we can begin this approach by creating a dictionary
reviews_max = {}

#adding app name and their maximum rating to reviews_max dictionary
for element in a_body:
    name = element[0]
    rating = float(element[3])
    
    if name in unique_apps:
        reviews_max[name] = rating
        
    else:
        temp_rating = reviews_max[name]
        if rating > temp_rating:
            reviews_max[name] = rating

reviews_max
# Out:
# {'Yaoi Novels - Shounen ai Book&fiction': 304.0,
#  'Wonder5 Masters R': 1655.0,
#  'New 2018 Keyboard': 298321.0,
#  'Air conditioner remote control': 29854.0,
#  'EO RAIPUR': 1.0,
#  'Tennis Champion 3D - Online Sports Game': 170973.0,
#  'Learn R Programming Full': 11.0,
#  'KBA-EZ Health Guide': 4.0,
#  'Pet Lovers Dating': 0.0,
#  'Sync for reddit': 62740.0,
#  'Solo Locker (DIY Locker)': 474439.0,
#  'BS Tractor': 3.0,
#  'EJ.by': 10.0,
#  'Comunidad BH': 23.0,
#  'Math Solver': 2250.0,
#  'codeSpark Academy & The Foos': 4522.0,
#  'EMI, FD, RD - Bank Calculator': 42.0,
#  'BlueDV AMBE': 0.0,
#  'PPS Online': 37.0,
#  'BG Products': 4.0,
#  'Florida Lottery Results': 763.0,
#  'Keep My Notes - Notepad & Memo': 122424.0,
#  'Build.com - Shop Home Improvement & Expert Advice': 118.0,
#  'Cyprus Police': 226.0,
#  'BuzzFeed: News, Tasty, Quizzes': 131028.0,
#  'German Listening': 18298.0,
#  'Ay Yıldız Analog Saat': 37.0,
#  'EGW Writings': 24278.0,
#  'Allrecipes Dinner Spinner': 61881.0,
#  'iCluster - The DX-Cluster database': 0.0,
#  'IF YOU TO EU PEGO': 3.0,
#  'iCam - Webcam Video Streaming': 770.0,
#  'Do Not Disturb': 6120.0,
#  'HTC Service—Video Player': 6449.0,
#  'Writing Wizard Premium - Handwriting': 89.0,
#  'BiggerCity: Chat for gay bears, chubs & chasers': 923.0,
#  'DN Sync': 56.0,
#  'DCUO|CR Calculator Lite': 182.0,
#  'BBMoji - Your personalized BBM Stickers': 8827.0,
#  'Orbita AI — Exciting mobile puzzles & riddles': 116973.0,
#  'USAA Mobile': 100997.0,
#  'Saiyan Z: Super SSJ Ultimate Combat': 306.0,
#  'MegaN64 (N64 Emulator)': 877576.0,
#  'Transfer': 31804.0,
#  'cx advance call blocker': 3.0,
#  'Hactar Go': 97.0,
#  'M Theme - Dark Green Icon Pack': 202.0,
#  'Dentist Surgery ER Emergency Doctor Hospital Games': 2580.0,
#  'think Comics': 1006.0,
#  'Soccer FC': 6289.0,
#  'Shiver: Moonlit Grove CE': 3433.0,
#  'Bathroom Decorating Ideas': 2427.0,
#  'All-night drugstore CI & Price': 0.0,
#  'Sago Mini Big City': 8.0,
#  'Pixelmania - Color by number & create pixel art': 3588.0,
#  'Cardi B HD Wallpapers Lock Screen': 2.0,
#  'Pedometer, Step Counter & Weight Loss Tracker App': 548021.0,
#  'The X-Files: Deep State - Hidden Object Adventure': 22018.0,
#  'Happy Fruits Bomb - Cube Blast': 2150.0,
#  'APagri CD': 5.0,
#  'Gmail': 4604324.0,
#  'MeetMe: Chat & Meet New People': 1259723.0,
#  'ActionDirector Video Editor - Edit Videos Fast': 74531.0,
#  'Nike Training Club - Workouts & Fitness Plans': 251618.0,
#  "BC's Pizza": 113.0,
#  'Onet - news, weather, sport': 13950.0,
#  'AE Jewels': 960.0,
#  'BL ONLINE PERSONAL TRAINING': 0.0,
#  'db Meter - sound level meter with data logging': 0.0,
#  'AU Students Zone (Result 2016)': 97.0,
#  'VAN NIAN 2018 - Vietnamese Calendar': 37.0,
#  'O Multiple - App Cloner, Duals APP, tarallel': 145.0,
#  'Sweet Baby Girl Newborn Baby': 36028.0,
#  'Alzashop.com': 32014.0,
#  'CT MyChiroTown Mobile': 40.0,
#  'DV 2019 - EDV Photo & Form': 314.0,
#  'Graffiti Letters (A-Z)': 386.0,
#  'Supervision service': 2155.0,
#  'Racing Moto': 697805.0,
#  'K keyboard - Myanmar': 1955.0,
#  "Michael's AG Sound Board": 0.0,
#  'BP Toolbox': 32.0,
#  'FOSSIL Q: DESIGN YOUR DIAL': 985.0,
#  'Adult Glitter Color by Number Book - Sandbox Pages': 8918.0,
#  'X-Plane to GPS': 161.0,
#  'Magnum 3.0 Gun Custom SImulator': 16815.0,
#  'All Video Downloader': 165723.0,
#  'City Driving Jeep Mania: Parking Passion 2018': 36.0,
#  'BN Pro Arial Legacy Text': 83.0,
#  'IBM Micromedex Drug Info': 206.0,
#  'Associated Credit Union Mobile': 3290.0,
#  '5-Minute Clinical Consult': 84.0,
#  'Arabic Alphabet Alif Ba Ta Wooden Blocks': 66.0,
#  'Cricket Visual Voicemail': 13698.0,
#  'Lords Mobile: Battle of the Empires - Strategy RPG': 3057481.0,
#  'Remote | Fire TV | Android TV | KODI | CetusPlay': 15911.0,
#  'Huntington Mobile': 11264.0,
#  'Cloud Print': 282460.0,
#  'English in a Month Free': 6577.0,
#  'CJ VLC HD Remote (+ Stream)': 4074.0,
#  'Van Nien 2018 - Lich Van su & Lich Am': 3829.0,
#  'Oxford Dictionary of English : Free': 364452.0,
#  'CB Mobile Access': 57.0,
#  'Nurse Grid': 1686.0,
#  'A hundred': 236.0,
#  'DRAGON BALL LEGENDS': 338742.0,
#  'Dark Infusion Substratum Theme for Android N & O': 133.0,
#  "Fill 'er Up": 58.0,
#  'Cooking Channel': 1033.0,
#  'Q-See QT View': 7357.0,
#  'DIY cd rom ideas': 5.0,
#  'Free & Premium VPN - FinchVPN': 19096.0,
#  '591 housing transactions - renting houses, middle-class houses, new cases, real-time registration, villas through the sky, apartment suites, MRT, buying a house selling prices, housing mortgages': 24977.0,
#  'Skin Disease': 1.0,
#  'CSHS BX': 0.0,
#  'FG. Chic - House Lounge Musique - Radios de France': 1.0,
#  'English-Myanmar Dictionary': 8788.0,
#  'Abs Training-Burn belly fat': 2071.0,
#  'EF Staff': 0.0,
#  'Read it easy for BK': 1.0,
#  'Texas Bar-B-Q Rewards': 0.0,
#  'Weather –Simple weather forecast': 40606.0,
#  'Launcher Theme for LG K10 2018': 649.0,
#  'Sufara.ba': 285.0,
#  'Basics of Orthopaedics': 1.0,
#  'Crackle - Free TV & Movies': 388089.0,
#  'DB Manager': 3.0,
#  'Y! Mobile menu': 9.0,
#  'Radarbot Free: Speed Camera Detector & Speedometer': 44348.0,
#  'GO Contacts EX Black & Grey': 21.0,
#  'Bed Time Fan - White Noise Sleep Sounds': 10097.0,
#  'CH Kadels': 36.0,
#  'Hidden Object Florida Vacation Adventure Fun Game': 126.0,
#  'Portable Wi-Fi hotspot Premium': 481.0,
#  'ALL-IN-ONE PACKAGE TRACKING': 167406.0,
#  'Multi Surgery Hospital Pro: Virtual Doctor ER Game': 23.0,
#  'Gas Station': 1288.0,
#  'Fr Lupupa Sermons': 19.0,
#  'Hide App, Private Dating, Safe Chat - PrivacyHider': 35205.0,
#  'CTRL-F - Search the real world': 607.0,
#  'DH-Security Camera': 3.0,
#  'AZ Immune Related AEManagement': 3.0,
#  'Zap-Map: EV charging points UK': 181.0,
#  'iGun Pro -The Original Gun App': 249308.0,
#  'BC browser': 1.0,
#  'CB Fit': 1.0,
#  'Al-Moazin Lite (Prayer Times)': 284670.0,
#  'Path': 1520959.0,
#  'Patook - make platonic friends': 3677.0,
#  'Ek Onkar Mantras': 82.0,
#  'CX_WiFiUFO': 818.0,
#  'AP Government Review': 3.0,
#  'AU Call Blocker - Block Unwanted Calls Texts 2018': 16.0,
#  'Bu Hangi Uygulama ?': 1.0,
#  'DK 15 Minute Language Course': 21.0,
#  'BMH-BJ Congregation': 0.0,
#  "Eat Right Diet (by Dt Shreya's Family Diet Clinic)": 0.0,
#  'Women"s Health Tips(Breast,Face,Body,weight lose)': 2509.0,
#  'bX Hot Articles by Ex Libris': 42.0,
#  'Revita.bg': 10.0,
#  'Magoosh GMAT Prep & Practice': 1058.0,
#  'Smashy Road: Arena': 45558.0,
#  'TN Patta Citta & EC': 48.0,
#  'Animal Hunting: Sniper Shooting': 0.0,
#  'Note Everything': 57033.0,
#  'DW - Breaking World News': 17671.0,
#  'CJ IT ApS': 0.0,
#  'ZenUI Keyboard – Emoji, Theme': 537554.0,
#  'GEM™': 6.0,
#  '+Download 4 Instagram Twitter': 40467.0,
#  'BF Beautiful Nature': 5.0,
#  'Target - now with Cartwheel': 68406.0,
#  'MYCU TX Mobile Banking': 4.0,
#  'Hurdlr: Track Mileage, Expenses, and Log Receipts': 3596.0,
#  'S Photo Editor - Collage Maker , Photo Collage': 972574.0,
#  'Find Fast Food': 272.0,
#  '95Live -SG#1 Live Streaming App': 4954.0,
#  'QR Code Reader': 495971.0,
#  'Google Drive': 2728941.0,
#  'Chat Rooms, Avatars, Date - Galaxy': 135420.0,
#  'Calvin Klein Petite Dresses': 0.0,
#  'Lose Belly Fat in 30 Days - Flat Stomach': 38098.0,
#  'GO Notifier': 124346.0,
#  'Earth to Luna! Watch and Play': 10753.0,
#  'Shooter Sniper CS - FPS Games': 14823.0,
#  'Sweet Selfie - selfie camera, beauty cam, photo edit': 1159058.0,
#  'Cx Wize': 3.0,
#  'Little Panda Run': 3235.0,
#  'Virtual Mother Surgery Doctor : Emergency Hospital': 70.0,
#  'Gravidez ao Vivo': 61.0,
#  'Fields of Battle': 71476.0,
#  'Yoga - Track Yoga': 7976.0,
#  'SH Script Runner': 334.0,
#  'Shopkins World!': 169609.0,
#  'Fitbit': 357417.0,
#  'TeachersPayTeachers': 828.0,
#  'Easy Voice Recorder': 205191.0,
#  'Stickman Legends: Shadow Wars': 38419.0,
#  'Defender': 152395.0,
#  'Sweet Camera': 71898.0,
#  'Be Stronger': 787.0,
#  'MC.Fitting': 130.0,
#  'DN': 78.0,
#  'Scientific Calculator Free': 16395.0,
#  'Flowers Live Wallpaper': 118459.0,
#  'Super Doctor 1-Pregnant Mom ER Surgery Simulator': 290.0,
#  'Dr. Battery - Fast Charger - Super Cleaner 2018': 101738.0,
#  'Mermaid Princess Pre K Games': 19.0,
#  "Cook 'n Learn Smart Kitchen": 205.0,
#  'ES Task Manager (Task Killer )': 171771.0,
#  'Counter Terrorist Gun Strike CS: Special Forces': 211.0,
#  'EK Bailey Preaching Conference': 3.0,
#  'Bloomberg: Market & Financial News': 61692.0,
#  'Best Ovulation Tracker Fertility Calendar App Glow': 56145.0,
#  '¡Ay Metro!': 489.0,
#  'White Noise for Baby': 717.0,
#  'Alabama Gameday Live': 19.0,
#  'Ay Up': 11.0,
#  'Web Browser ( Fast & Secure Web Explorer)': 2508.0,
#  'MDLIVE: Talk to a Doctor 24/7': 650.0,
#  'BV Smart': 28.0,
#  'Blur': 9013.0,
#  'Websites.co.in Instant Website': 327.0,
#  'Future Cloud': 1075.0,
#  'Mirror': 367505.0,
#  'love sms good morning': 10.0,
#  'Můj T-Mobile Business': 10490.0,
#  'Bee Mobile EG': 883.0,
#  'ER Emergency Hospital - Brain, Knee, Eye Surgery': 25.0,
#  'AK47 Assault Rifle': 54.0,
#  'PBS KIDS Games': 12919.0,
#  'English Audio Books - Librivox': 10773.0,
#  'Coloring Book at Five Nights': 532.0,
#  'ba': 1734.0,
#  'Elevate - Brain Training Games': 248912.0,
#  'Magisto Video Editor & Maker': 960726.0,
#  'Cisco Webex Teams': 1661.0,
#  'DP & Status': 1922.0,
#  'ibis Paint X': 224399.0,
#  'EZ Switch Widget': 2412.0,
#  'Text on Photo - Fonteee': 13880.0,
#  'CW TV': 367.0,
#  'Dog Sim Online: Raise a Family': 94989.0,
#  'Sports Lite': 16.0,
#  'PulsePoint Respond': 7837.0,
#  'Tie - Always be happy': 964.0,
#  'BakaReader EX': 8894.0,
#  'Victoria EC': 5.0,
#  'TAMAGO Monsters Returns': 104583.0,
#  'Account Class-11 Solutions (D K Goel)': 663.0,
#  "Kinot & Eichah for Tisha B'Av": 98.0,
#  'B.GOOD': 155.0,
#  'Noticias FC Barcelona': 4.0,
#  'RC City Police Heavy Traffic Racer': 3250.0,
#  'Baby Panda Learns Shapes': 3789.0,
#  'Texas HoldEm Poker Deluxe': 396090.0,
#  'Chinese Chess 3D Online (Xiangqi, 象棋, co tuong)': 23.0,
#  'Champions and Challengers - Adventure Time': 51973.0,
#  'Top Puzzles Volvo FH Trucks': 4.0,
#  'weather - weather forecast': 11118.0,
#  'AZ Rockets': 162.0,
#  'AMBW Dating App: Asian Men Black Women Interracial': 2.0,
#  'Ek-yatri: Travel where you Belong': 0.0,
#  'D.C. Driving/Walking Tours': 0.0,
#  'Whisper': 205803.0,
#  'DW Contacts & Phone & Dialer': 21186.0,
#  'Themes DAF CF 85': 3.0,
#  "We're Working Out - Al Kavadlo": 979.0,
#  'BK Murli Offline April 2017': 33.0,
#  'CS go bomb simulator': 7.0,
#  'Lookout Security & Antivirus': 951413.0,
#  'Battery Notifier BT Free': 21979.0,
#  'Handbreit by a.w.niemeyer': 21.0,
#  'postit.bm': 1.0,
#  'T-Mobile': 482630.0,
#  'HD Video Player (wmv,avi,mp4,flv,av,mpg,mkv)2017': 171.0,
#  'CV Builder': 203.0,
#  'EU CBRNE Glossary': 3.0,
#  '3D Metal Piano Keys Keyboard Theme': 467.0,
#  'How it Works: FN SCAR assault rifle': 44.0,
#  'Navigator PRO - GPS Navigation with Offline Maps': 892.0,
#  '¿Es Vegan?': 438.0,
#  'ChopAssistant': 455.0,
#  'Snes9x EX+': 70351.0,
#  'Brica BPRO5 AE': 4726.0,
#  'Moony Lab - Print Photos, Books & Magnets ™': 1320.0,
#  'Public Service CU Mobile': 314.0,
#  'Q MINDshare Mobile': 24.0,
#  'WPS Office - Word, Docs, PDF, Note, Slide & Sheet': 1507205.0,
#  'Teen Titans GO Figure!': 1985.0,
#  'Google Play Movies & TV': 906384.0,
#  'Relax Ocean ~ Nature Sounds': 9464.0,
#  'MbH BP': 9.0,
#  'Discovery Church Florida': 40.0,
#  'photo keypad lockscreen': 225544.0,
#  'iPlayIT for YouTube VR Player': 5879.0,
#  'Lexus Tech BH Service Pro': 0.0,
#  'Flippy Axe : Flip The Knife & Axe Simulator': 7.0,
#  'SVT Play': 11549.0,
#  'Florida Offline Road Map': 144.0,
#  'CE BF': 0.0,
#  'Ringtones Of Ek Onkar': 6.0,
#  'Bible Quizzer - The App for Bible Quizzers': 0.0,
#  'AQ: First Contact': 0.0,
#  'Squeezy CF': 0.0,
#  'Ice Crush 2018 - A new Puzzle Matching Adventure': 15403.0,
#  'Ek Qissa He Quran Se (Qurani Waqiyat)': 4.0,
#  'Azpen eReader': 156.0,
#  'Rento - Dice Board Game Online': 205830.0,
#  'Free Book Reader': 1680.0,
#  'Vintage Flower CM Locker Theme': 2910.0,
#  'ES File Explorer File Manager': 5378795.0,
#  'BN Pro BlueICS-b HD Text': 78.0,
#  'Golden Dictionary (FR-AR)': 5775.0,
#  'Trane Interactive Smart AC': 48.0,
#  '101 C Programming Problems': 498.0,
#  'FH WiFiCam': 201.0,
#  'NoteToDo. Notes. To do list': 57449.0,
#  'CG Fit Scale': 13.0,
#  'Morse Decoder for Ham Radio': 166.0,
#  'Calorie Counter - MyFitnessPal': 1873523.0,
#  'Battery Doctor-Battery Life Saver & Battery Cooler': 8190074.0,
#  'Hidden Objects Treasure Hunt Adventure Games': 275.0,
#  'CM Apps': 3341.0,
#  'BG Middle East': 1.0,
#  'ec-Work': 3.0,
#  'Fast Download Manager': 18478.0,
#  'Gold Butterfly Keyboard Theme': 10054.0,
#  'Dr. Parker : Parking Simulator': 14253.0,
#  'Benefit Extras Mobile App': 3.0,
#  'Airplane Fly Hawaii': 83427.0,
#  "Jump'N'Shoot Attack": 155.0,
#  'FNH Payment Info': 0.0,
#  'BF games': 262.0,
#  'Punch em': 2208.0,
#  'Bg TV Online': 50.0,
#  'Advanced EX for MITSUBISHI': 33.0,
#  'NetSpend Prepaid': 15993.0,
#  'NPR News': 24790.0,
#  'METEO FRANCE': 100994.0,
#  'RetailMeNot - Coupons, Deals & Discount Shopping': 210208.0,
#  'Soldiers of Glory: Modern War': 64815.0,
#  'Bomber Friends': 776730.0,
#  'Axetatic - Axe Throwing Game': 29.0,
#  'El Nuevo Día': 8011.0,
#  'File Browser by Astro (File Manager)': 609182.0,
#  'Dating White Girls': 0.0,
#  'BaBe Lite - Read Quota Saving News': 9548.0,
#  'Day R Premium': 51068.0,
#  'F-Secure SENSE': 57.0,
#  'Koi Live Wallpaper': 14026.0,
#  'ADW Launcher 2': 181399.0,
#  'Luxury Car Simulator': 35989.0,
#  'Go Go Coupons - Free Coupon and Discount': 4.0,
#  'Ultimate Calculator for CR': 7389.0,
#  'eP Scanner': 0.0,
#  'BV Bombers': 0.0,
#  '¡Ay Caramba!': 0.0,
#  'Pinkalicious Party': 2.0,
#  'FOX': 197774.0,
#  'Adobe Acrobat Reader': 3014548.0,
#  'Yoga Studio: Mind & Body': 5499.0,
#  '【Ranobbe complete free】 Novelba - Free app that you can read and write novels': 1330.0,
#  'My College Bookstore': 661.0,
#  'Learn JavaScript': 25183.0,
#  'Offroad 4x4 Car Driving': 26224.0,
#  'Tokyo Ghoul: Dark War': 25094.0,
#  'Gaode Map': 13275.0,
#  'Meritrust CU Mobile Banking': 3661.0,
#  'Digi-TV.ch': 62.0,
#  'MommyMeds': 45.0,
#  'S’more - Earn Cash Rewards': 15097.0,
#  'SW-100.tch by Callstel': 1926.0,
#  'AG Subway Simulator Lite': 6738.0,
#  'LOBSTR - go on a lunch date': 101.0,
#  'Zoo For Preschool Kids 3-9 Years': 76.0,
#  'CA Latam Partners': 0.0,
#  'Toy Battle Z': 133.0,
#  'AV HD Video Player': 6.0,
#  'Preschool All-In-One': 9019.0,
#  'EF Events': 7.0,
#  'Amtrak': 16815.0,
#  'HBO NOW: Stream TV & Movies': 61230.0,
#  'Camera ZOOM FX - FREE': 88860.0,
#  'Asana: organize team projects': 20815.0,
#  'Eyes - The Scary Horror Game Adventure': 499483.0,
#  'Lose Weight in 30 Days': 220125.0,
#  '9GAG: Funny Gifs, Pics, Memes & Videos for IGTV': 1450632.0,
#  'NETGEAR WiFi Analytics': 9496.0,
#  'FK Viktoria Žižkov': 0.0,
#  'Best Wallpapers QHD': 294701.0,
#  'Lab Values + Medical Reference': 133.0,
#  'Photo Editor': 114680.0,
#  'Stickers for Imo, fb, whatsapp': 214.0,
#  'My FR App': 2.0,
#  'K-Chiing VPN (Free)': 43.0,
#  'Last Day on Earth: Survival': 2308916.0,
#  'Masha and the Bear': 15105.0,
#  'Team CF': 0.0,
#  'OpenGL-ES Info': 249.0,
#  'Google Sheets': 496397.0,
#  'Dirt Trackin Sprint Cars': 499.0,
#  'Living Smart Home': 39189.0,
#  'K-pop Music': 369.0,
#  'How to sew & make the easiest pattern': 110.0,
#  'Assemblr - Create 3D Models (Sandbox AR)': 1745.0,
#  'Free Cam Girls - Live Webcam': 35.0,
#  'WiseBanyan - Invest For Free': 257.0,
#  'STARDOM: THE A-LIST': 152658.0,
#  'Pureness Pacify (Android P) - Theme for Xperia™': 0.0,
#  'VMate': 192677.0,
#  'EU Flag Live Wallpaper': 19.0,
#  'Deaf - Hearing chat device H': 9.0,
#  'GoodRx Drug Prices and Coupons': 59158.0,
#  'Theme for Iphone X Plus': 126.0,
#  'XML Editor CR': 47.0,
#  "Hey AJ! It's Bedtime!": 1.0,
#  'One Today by Google': 2586.0,
#  'Trinity Church Deltona, FL': 33.0,
#  'Guide for CS:GO': 16459.0,
#  'My Vodacom SA': 25021.0,
#  'iCard BD Plus': 2.0,
#  'Bh Public School': 2.0,
#  'Sokoban Land DX': 46.0,
#  'Dino in City-Dinosaur N Police': 10035.0,
#  'Draw N Guess Multiplayer': 29505.0,
#  'Textgram - write on photos': 295237.0,
#  'Dynamics AX': 244.0,
#  'CABLE SIZE CALCULATOR BS 7671': 333.0,
#  'Mukwonago AH': 1.0,
#  'Mass Effect: Andromeda APEX HQ': 4490.0,
#  'Metal Detector Pro 2015': 1166.0,
#  'MYTO CZ': 30.0,
#  'Yahoo Mail – Stay Organized': 4188345.0,
#  'BQ Services': 5004.0,
#  'BD TYCOON': 16.0,
#  'Facial Wrinkle Reduction': 184.0,
#  'Five nights at Minecraft': 9335.0,
#  'BF Combat: Genesis': 3322.0,
#  'Gold Teeth Photo Editor': 1022.0,
#  'Launcher Oreo 8.1': 13466.0,
#  'Microsoft News': 31504.0,
#  'PlusOne': 0.0,
#  'VictronConnect': 400.0,
#  'DX Glow - Clock Widget': 5.0,
#  'DX Simulation Belt for Decade henshin': 64.0,
#  'e-Boks.dk': 6752.0,
#  'BT Communicator': 32.0,
#  'AcDisplay': 66473.0,
#  'RPG End of Aspiration F': 20368.0,
#  'Voxer Walkie Talkie Messenger': 230564.0,
#  'RTVBN': 533.0,
#  'San Andreas City : Auto Theft Car gangster': 923.0,
#  'Fertility Friend Ovulation App': 12955.0,
#  'Google Translate': 5741684.0,
#  'Train driving simulator': 91645.0,
#  'DB Ultra Saiyan Battle': 33.0,
#  'Easy Recipes': 2707.0,
#  'R Programming Tutorial': 5.0,
#  'DW Tech Tools': 1.0,
#  'CI Staff App': 0.0,
#  'Masha and the Bear. Games for kids': 6231.0,
#  'ING Banking': 39041.0,
#  'QuickBooks Accounting: Invoicing & Expenses': 23175.0,
#  '850 Sports News Digest': 539.0,
#  'Shoot! DX - lights for FREE': 4.0,
#  'Gainesville Florida Police Department': 4.0,
#  'Pedometer': 400592.0,
#  'Once - Quality Matches Every day': 222888.0,
#  'World Travel Guide by Triposo': 6012.0,
#  'TouchPal Keyboard for vivo': 357.0,
#  'Safe Santa Fe': 2.0,
#  'EZ Financial Calculator': 32.0,
#  'Blood Injection : ER Emergency Doctor ER injection': 246.0,
#  'myGrow': 84.0,
#  'Diseño de columnas NTC - RSEE 2017': 6.0,
#  'Automatic Call Recorder': 1648515.0,
#  'EG-Boost': 25.0,
#  'Anonymous caller detection': 161.0,
#  'Make your Be Like Bill': 78.0,
#  'Open Sesame - Touch Free Control': 197.0,
#  'LEGO® Friends': 854.0,
#  'Calorie Counter by FatSecret': 229214.0,
#  'AV Phone': 4.0,
#  'Advanced EX for NISSAN': 164.0,
#  'Kids Educational Game 3 Free': 24936.0,
#  'Nick': 123309.0,
#  'Top Soccer Manager': 199739.0,
#  'US DV Lottery 2020 Apply': 41.0,
#  'FQ Magazine': 1.0,
#  'The birth': 1084945.0,
#  'Ba Financial Calculator plus': 31.0,
#  'eBiblio': 2907.0,
#  "You're an Anime": 2.0,
#  'Selfie With Champion AJ Style': 2.0,
#  'Jodel - The Hyperlocal App': 76480.0,
#  'Ultimate DC Challenge': 937.0,
#  'With Helper Pro Pill Reminder': 358.0,
#  'AMC Theatres': 44550.0,
#  'Brainf*ck Interpreter': 24.0,
#  'KineMaster – Pro Video Editor': 1013867.0,
#  'Fruit Ninja Classic': 85468.0,
#  'Desperate Housewives: The Game': 10440.0,
#  'SeriesGuide – Show & Movie Manager': 64448.0,
#  'Google Duo - High Quality Video Calls': 2083237.0,
#  'Youboox - Livres, BD et magazines': 4071.0,
#  'BS Meter (Ad Supported)': 14.0,
#  'Denis Brogniart - AH 2 !': 4.0,
#  'Duolingo: Learn Languages Free': 6297590.0,
#  'Tuberculose Dz': 26.0,
#  'Hot Bhojpuri Video Song 2018 - Free Movies': 447.0,
#  'Servidor Privado de CR y CoC - Light Royale': 3106.0,
#  'Ak-47 Wallpapers 2018': 7.0,
#  'Colors of white in Urdu': 36.0,
#  'C Examples': 1002.0,
#  'Darkness Rises': 456474.0,
#  "Please Don't Touch Anything 3D": 146.0,
#  'Evolution: Battle for Utopia': 246705.0,
#  'CB Frequencies': 5.0,
#  'Freeland AH': 0.0,
#  'Evolution CP': 13.0,
#  'Learn Bulgarian Free': 3049.0,
#  'Centimeter Ruler': 16.0,
#  'Cars Coloring Pages': 1090.0,
#  'PPCNP-BC Pocket Prep': 3.0,
#  'Classic Calculator': 85659.0,
#  'World Newspapers': 185884.0,
#  'Lock Screen': 41137.0,
#  'Microsoft Power BI–Business data analytics': 1819.0,
#  'Common Core': 835.0,
#  'Dermatology Atlas (Colored & Illustrative)': 3.0,
#  'Stats CR Clan for Clash Royale': 16.0,
#  'Greeting Cards & Wishes': 17350.0,
#  'Monastery of El Escorial': 12.0,
#  'Sleeping Delivery': 19640.0,
#  'Project Fi by Google': 7342.0,
#  'dB Sound Level Meter': 203.0,
#  'Lesbian Chat & Dating - SPICY': 63765.0,
#  'BD Bank Interest': 289.0,
#  'Eternal life': 26.0,
#  'Amazon Shopping': 908525.0,
#  'Remote For ATT U-verse TV - NOW FREE': 20.0,
#  'TNEB': 1777.0,
#  '3D Color by Number with Voxels': 5481.0,
#  'App Seguridad AV Villas': 251.0,
#  'CppDroid - C/C++ IDE': 29978.0,
#  'Photo Frame': 74476.0,
#  'PLAYzone.cz': 14.0,
#  'EG SIM CARD (EGSIMCARD)': 105.0,
#  'Out There Chronicles - Ep. 1': 1516.0,
#  'Body scanner (prank)': 16063.0,
#  'HSPA+ Tweaker (3G booster)': 99290.0,
#  'Wifi BT Scanner': 2.0,
#  "Don't Panic with Andrew J.": 124.0,
#  'Draw In': 46416.0,
#  'GATE CS Engineering 2019 Exam Prep App': 162.0,
#  'Battery Calibration': 134412.0,
#  "Dunkin' Donuts": 68270.0,
#  'HTC Sense Input': 17030.0,
#  'HD Camera - Quick Snap Photo & Video': 21841.0,
#  'Canva: Poster, banner, card maker & graphic design': 174531.0,
#  'CR -Call Recorder': 4.0,
#  'BT Remote (SPP) for Bluetooth': 36.0,
#  'CJ - BR MEMES': 109.0,
#  'Tiny Scanner Pro: PDF Doc Scan': 10295.0,
#  'K PLUS': 124324.0,
#  'English Bite': 268.0,
#  'Aegis BT': 16.0,
#  'Diabetes:M': 15537.0,
#  'EO Mumbai': 0.0,
#  'AP Themes for Kustom/KLWP': 5.0,
#  "CJ's Tire & Automotive": 5.0,
#  'Top Popular Ringtones 2018 Free 🔥': 7396.0,
#  'Ag Tools': 2.0,
#  'Golden Launcher': 32794.0,
#  'CL Keyboard - Myanmar Keyboard (No Ads)': 24.0,
#  '4 x4 Offroad SUV 3D Truck Simulator Driving 2017': 32.0,
#  "Poker Live! 3D Texas Hold'em": 6143.0,
#  'GolfLogix GPS + Putt Breaks': 11085.0,
#  'Shopee: No.1 Online Shopping': 608753.0,
#  'Samsung Notes': 15368.0,
#  'Citizens Bank Mobile Banking': 15192.0,
#  'CR Calculator': 297.0,
#  'My Little Pony Rainbow Runners': 33785.0,
#  'Ethical Hacking': 128.0,
#  'Learn Italian with MosaLingua': 1719.0,
#  'WhatsApp Messenger': 69109672.0,
#  'DW Contacts Wear': 37.0,
#  'Furrion ES Control': 26.0,
#  'Jewels Legend - Match 3 Puzzle': 280098.0,
#  'Chest Calculator for CR': 14754.0,
#  'Wifi Mingle': 0.0,
#  'Advanced Download Manager': 569727.0,
#  'BPme - Mobile Fuel Payment & BP Driver Rewards app': 69.0,
#  'DP and Status Images | All Latest Status 2018': 25.0,
#  'Dungeon Keeper': 69574.0,
#  'Adult Color by Number Book - Paint Mandala Pages': 997.0,
#  'DRAGON QUEST IV': 1647.0,
#  'GoBank': 5950.0,
#  'I Screen Dialer': 8137.0,
#  'BN Pro RobotoXL HD Text': 15.0,
#  'Talking Husky Dog': 26545.0,
#  'EC Fairgrounds': 3.0,
#  'Cp Calculator for Evolution:GO': 124.0,
#  'Android-P Mono Grey EMUI 8/5 Theme': 61.0,
#  'VitusVet: Pet Health Care App': 3052.0,
#  'DM Talk New': 3.0,
#  'Real estate court auction information site - Hyundai court auction': 10.0,
#  'Theme for Galaxy Note FE': 3.0,
#  'DG Cars': 122.0,
#  'letgo: Buy & Sell Used Stuff, Cars & Real Estate': 972256.0,
#  'Socrative Teacher': 1239.0,
#  '2Do - Reminders, To-do List & Notes': 4649.0,
#  'S Launcher for Galaxy TouchWiz': 11244.0,
#  'Claus Paws AH': 1.0,
#  'iBP Blood Pressure': 578.0,
#  'BH Mission Playbook': 0.0,
#  'Does not Commute': 154108.0,
#  'Nature Sounds': 28588.0,
#  'Goibibo - Flight Hotel Bus Car IRCTC Booking App': 459851.0,
#  'Viki: Asian TV Dramas & Movies': 407719.0,
#  'JoJo Siwa Top Hits Music': 0.0,
#  'Barca News - app for Barcelona FC Fans': 207.0,
#  'Gems or jewels ?': 171448.0,
#  'Squid - Take Notes & Markup PDFs': 37204.0,
#  'Baby Name Together': 464.0,
#  'Alfa-Bank (Alfa-Bank)': 44545.0,
#  '4 in a row': 47698.0,
#  'Idle Heroes': 417197.0,
#  'Aunjai i lert u': 1140.0,
#  'FIFA 16 Soccer': 820577.0,
#  'Météociel': 29344.0,
#  'A Better Camera': 76484.0,
#  'Six Packs for Man–Body Building with No Equipment': 2880.0,
#  'Snag - Jobs Hiring Now': 32584.0,
#  'TouchPal Purple Butterfly Theme': 7435.0,
#  'Empires and Allies': 398746.0,
#  'Sensenuts eI': 0.0,
#  'Penny Puss': 19.0,
#  'Clear': 24151.0,
#  'FH Dortmund FB4': 40.0,
#  'Traffic Racer': 5387781.0,
#  'BD Briight: Your Diabetes Personal Assistant': 17.0,
#  'The List': 66.0,
#  'CV S ( CV Editor - Resume )': 3972.0,
#  'Sir C J New Primary School': 3.0,
#  'DK TEL Dialer': 0.0,
#  'F': 6.0,
#  'Cx File Explorer': 175.0,
#  'AP Manager': 177.0,
#  'NBA JAM by EA SPORTS™': 56444.0,
#  'Wi-Fi Visualizer': 132.0,
#  'Ei Samay - Bengali News Paper': 20620.0,
#  'Live chat - free video chat': 1.0,
#  'Free Books - Spirit Fanfiction and Stories': 116507.0,
#  'Theme Android P for LG G7 & V35': 5.0,
#  'EML UPnP-AV Control Point': 78.0,
#  'Planner Pro-Personal Organizer': 10270.0,
#  'Color Call - Caller Screen, LED Flash': 29485.0,
#  'BG-FLEET': 0.0,
#  'myMail – Email for Hotmail, Gmail and Outlook Mail': 305218.0,
#  'Crisis Action: 2018 NO.1 FPS': 807226.0,
#  'Burnley FC': 195.0,
#  'BF at Sea Refueled': 1849.0,
#  'Spine- The dating app': 5.0,
#  'No Crop & Square for Instagram': 819694.0,
#  'EZ Quran': 595.0,
#  'Baby Monitor': 5343.0,
#  'Bangla Calendar 1425: (EN-BN-AR) Holiday': 31.0,
#  'GUYZ - Gay Chat & Gay Dating': 41269.0,
#  'BN PERKS™': 0.0,
#  'Plug-in app (System AC)': 126.0,
#  'FK Železiarne Podbrezová': 0.0,
#  'Garden Fruit Legend': 4289.0,
#  'BP Tracker': 12.0,
#  'Bubble Shooter DX AdFree': 1.0,
#  'Offroad Oil Tanker Driver Transport Truck 2019': 542.0,
#  'ezETC (ETC balance inquiry, meter trial, real-time traffic)': 38846.0,
#  'Mi Remote controller - for TV, STB, AC and more': 114340.0,
#  'HACH Cares': 0.0,
#  'Xero Accounting Software': 2111.0,
#  'AMC': 20843.0,
#  'BK Suraj bhai': 9.0,
#  'Pro 2018 - Series A and B': 101455.0,
#  'Q-slope': 2.0,
#  'My CW': 1.0,
#  'Au Bon Pain': 70.0,
#  'Beach Volleyball 3D': 43191.0,
#  'Cymera Camera- Photo Editor, Filter,Collage,Layout': 2418165.0,
#  'NissanConnect® EV & Services': 853.0,
#  'British Airways': 25726.0,
#  'A & B Taxi': 41.0,
#  'Tattoodo - Find your next tattoo': 7457.0,
#  'Daily Workouts - Exercise Fitness Routine Trainer': 134195.0,
#  'MyAV Remote for Denon & Marantz AV Receivers': 250.0,
#  'Fake Call - Fake Caller ID': 154668.0,
#  'Clean My House – Chore To Do List, Task Scheduler': 661.0,
#  'EF Calculator': 19.0,
#  'BQ Wings': 1.0,
#  'Hello Stars': 101686.0,
#  'Tigo Money El Salvador': 4642.0,
#  'JavaScript Editor CR': 114.0,
#  'Sam.BN': 83.0,
#  'ZOOKEEPER DX TouchEdition': 3195.0,
#  'FD VR Player - for 360 Youtube': 100.0,
#  'C J Academy': 0.0,
#  'Klara weather': 36900.0,
#  'USMLE Step 2 CK Flashcards': 1.0,
#  'S Player - Lightest and Most Powerful Video Player': 14224.0,
#  'Read books online': 91615.0,
#  'Offline Maps & Navigation': 193364.0,
#  'Reminder': 7074.0,
#  'Auto Dslr Photo Effect : Auto Focus Effect': 6.0,
#  'Happify': 1812.0,
#  'Real Sheet ∞: Pathfinder + DT': 2.0,
#  'BV Taxi Sudan': 8.0,
#  'Eshopcy.com.cy': 182.0,
#  'Fruits Bomb': 74695.0,
#  'Get Over Your Ex': 10.0,
#  'Dash Tag - Fun Endless Runner!': 6750.0,
#  'RT 516 VET': 0.0,
#  'Everlance: Free Mileage Log': 7514.0,
#  'Reindeer VPN - Proxy VPN': 7339.0,
#  'Limbo PC Emulator QEMU ARM x86': 13005.0,
#  'Swift Dark CM / CM13 Theme': 1500.0,
#  'The Cube': 70226.0,
#  'Galaxy Attack: Alien Shooter': 506593.0,
#  'Horses Live Wallpaper': 28806.0,
#  'Water Garden Live Wallpaper': 66453.0,
#  'Pacifica - Stress & Anxiety': 10253.0,
#  'Bacteria Vaginosis': 4015.0,
#  'Learn Body Parts in English': 7243.0,
#  'বাংলাflix': 1111.0,
#  'BA Status': 0.0,
#  '2GIS: directory & navigator': 768833.0,
#  'FINAL FANTASY V': 15924.0,
#  'Cool Reader': 246315.0,
#  'Info BMKG': 21404.0,
#  "Shop 'n Save": 620.0,
#  'Cars: Lightning League': 58795.0,
#  'EB Experience': 0.0,
#  'F05WatchFace for Android Wear': 127.0,
#  'DW Maps': 35.0,
#  'ES Classic Theme': 20865.0,
#  'C-E Federal Credit Union': 1.0,
#  'Football-CB GO Clock Theme': 26.0,
#  'VAT check CY': 0.0,
#  'DM security - Dragon Mobile': 27.0,
#  'CT Scan Cross Sectional Anatomy': 10.0,
#  '360 Security - Free Antivirus, Booster, Cleaner': 16771865.0,
#  'AG Subway Simulator Pro': 0.0,
#  'Smart Launcher Pro 3': 40704.0,
#  'Profile Pictures - Best DP Status': 131.0,
#  'DQ Events': 41.0,
#  'bk Group Mobile': 1.0,
#  'BU Alsace': 3.0,
#  'CamScanner (License)': 26358.0,
#  'CCP DZ : Fill out a check | Number in letters DZD': 642.0,
#  'BT Satmeter': 0.0,
#  'GO SMS Pro Z Glass Theme EX': 24198.0,
#  'IndiGo': 48082.0,
#  'Anatomy Learning - 3D Atlas': 72167.0,
#  'My Cancer Coach': 44.0,
#  'ELMO EV Charging': 14.0,
#  'Free Wi-fi HotspoT': 382.0,
#  'Gang Wars of San Andreas': 9898.0,
#  'Binaural Beats Therapy': 13724.0,
#  'EF Teacher': 16.0,
#  'Intesa Sanpaolo Mobile': 35518.0,
#  'PhotoScan by Google Photos': 61990.0,
#  'BLACKJACK!': 524467.0,
#  'BC Hospital Wait Times': 8.0,
#  'CI Capital - Dynamic': 4.0,
#  'La La-Shop Designer Brands Street': 5123.0,
#  'I am rich (Most expensive app)': 129.0,
#  'Google Classroom': 69498.0,
#  'AK 47 Guns Wallpaper': 322.0,
#  'Voice Lock Screen': 6667.0,
#  'The Voice, sing and connect': 405824.0,
#  'Moto Suggestions ™': 308.0,
#  'OffRoad US Army Train Driving Simulator': 1216.0,
#  'Aab e Hayat Full Novel': 1476.0,
#  'Pick-a-Paint': 242.0,
#  'EZ LED': 19.0,
#  'StudentLife.com.cy': 17.0,
#  'All-in-One Mahjong 3 FREE': 566.0,
#  'DF BugMeNot': 7.0,
#  'Master of Eternity(MOE)': 5829.0,
#  'ORLANDO FLORIDA MAP': 3.0,
#  'CD CHOICE TUBE': 10.0,
#  'Calm - Meditate, Sleep, Relax': 111455.0,
#  'FQ - Football Quiz': 1.0,
#  'Typical EA Game': 33.0,
#  'Shrimp skin shopping: spend less, buy better': 106798.0,
#  'Cisco Webex Meetings': 108741.0,
#  'Chat Anónimo Gratis Español CG': 69.0,
#  'VivaVideo - Video Editor & Photo Movie': 9879473.0,
#  'The Visitor': 39895.0,
#  'BV Rando': 0.0,
#  'Meu Cartão BV': 15057.0,
#  'GATE Syllabus for EC 2018 & Notifications': 23.0,
#  'Fat Burning Workout - Home Weight lose': 706.0,
#  'Touch Racing 2 - Mini RC Race': 41867.0,
#  'El Pollo Loco - Loco Rewards': 848.0,
#  'DHgate-Shop Wholesale Prices': 104068.0,
#  'DINO HUNTER: DEADLY SHORES': 1381624.0,
#  'Numbers Into Words': 457.0,
#  'Dr. ES PV Calculator': 19.0,
#  'Union League': 939.0,
#  'Rized ‼️ Color By Number & Pixel Coloring Book': 1279.0,
#  'Howlr': 105.0,
#  'DC Universe Quiz': 11.0,
#  'Universal Kids': 1968.0,
#  'BEYBLADE BURST app': 216849.0,
#  'Minwa HA ( C.B )': 0.0,
#  'TANGEDCO Mobile App (Official)': 2915.0,
#  'IHOP®': 441.0,
#  'The CW': 288209.0,
#  'Face Filter, Selfie Editor - Sweet Camera': 142758.0,
#  'Overcomers CF - GA': 7.0,
#  "HAWK – Force of an Arcade Shooter. Shoot 'em up": 190274.0,
#  'The Divine Feminine App: the DF App': 8.0,
#  'Cryptocurrency Trading - How To Trade Crypto': 1.0,
#  "CJ Wilson's ZoomZoomnation": 4.0,
#  'Notepad & To do list': 226295.0,
#  'Free intellectual training game application |': 5741.0,
#  'HTC Sense Input - CZ': 87.0,
#  'Ay': 11.0,
#  'Maps & GPS Navigation OsmAnd+': 15209.0,
#  'ER': 2.0,
#  'Kovax Europe B.V.': 17.0,
#  'Quake & Volcanoes: 3D Globe of Volcanic Eruptions': 663.0,
#  'Doctor On Demand': 18674.0,
#  'DM Accounting and Payroll': 0.0,
#  'Adult Dirty Emojis': 80.0,
#  'Questland: Turn Based RPG': 31134.0,
#  'Dominos Game ✔️': 2903.0,
#  'iHoroscope - 2018 Daily Horoscope & Astrology': 398307.0,
#  'DS Speedometer & Odometer': 22382.0,
#  'KAYAK Flights, Hotels & Cars': 216388.0,
#  'How do I take care of my child?': 190.0,
#  'To-U - free EV public charging': 75.0,
#  'Color by Number: Pixel Art': 12034.0,
#  'CD - Teach me ABC English L1': 2.0,
#  'A/C Air Conditioner Remote': 7816.0,
#  'Girls Nancy Ajram Without Net': 2639.0,
#  'GS SHOP': 44255.0,
#  'Software Update': 8259.0,
#  'Standoff 2': 299046.0,
#  'Ruler(cm, inch)': 2889.0,
#  'Ba dum tss - Rimshot widget': 690.0,
#  'Epocrates Plus': 23889.0,
#  'Smart Air Conditioner': 4786.0,
#  'Looper!': 48256.0,
#  'FO PSA Sept-Fons': 2.0,
#  'THE KING OF FIGHTERS-A 2012(F)': 406511.0,
#  'Open Heart Surgery Hospital ER: Crazy Doctor Sim': 7.0,
#  'DW Arabic By dw-arab.com': 386.0,
#  'Learn R Language Easy Way': 17.0,
#  'Northern Lights FREE (Aurora)': 12180.0,
#  'music (CG)': 0.0,
#  "I Can't Wake Up! Alarm Clock": 70404.0,
#  'CP Federal Mobile': 180.0,
#  'Sync.ME – Caller ID & Block': 205739.0,
#  'Ivanti AE Agent': 1.0,
#  'MakeMyTrip-Flight Hotel Bus Cab IRCTC Rail Booking': 599872.0,
#  'Counter Terrorist Attack': 145931.0,
#  'BC Wildfire': 27.0,
#  'DC Legends: Battle for Justice': 355613.0,
#  'Tamago egg': 49.0,
#  'Glowing Flowers Live Wallpaper': 66730.0,
#  'Selfie Photo Editor': 11677.0,
#  'Plants vs. Zombies™ Heroes': 379245.0,
#  'EF Universe: Endless Battle': 5.0,
#  'eChallan Andhra Pradesh (AP)': 5.0,
#  'Story Time FD': 2.0,
#  'Prosperity': 16.0,
#  'Socratic - Math Answers & Homework Help': 37862.0,
#  'Jabong Online Shopping App': 367290.0,
#  'BitTorrent®- Torrent Downloads': 641219.0,
#  'Motocross Motorbike Simulator Offroad': 51366.0,
#  'CX Network': 0.0,
#  'HEAD TRAUMA CT EVALUATION': 18.0,
#  'La Fe de Jesus': 8.0,
#  'AJ Styles Wallpaper 2018 - AJ Styles HD Wallpaper': 18.0,
#  'Asylum Night Shift - Five Nights Survival': 59223.0,
#  'Lady adviser (beauty, health)': 30.0,
#  'Piczle Lines DX': 281.0,
#  'C.B. Shop': 19.0,
#  'Chatting - Free chat, random chat, boyfriend, girlfriend': 2506.0,
#  'Snapseed': 823109.0,
#  'EJ Trívia Game': 1.0,
#  'Antenna Tool Premium': 14.0,
#  'Fuzzy Numbers: Pre-K Number Foundation': 21.0,
#  'CB TV': 2.0,
#  'db.Mobil App': 23.0,
#  'Ag PhD Soils': 3.0,
#  'Gangster Town': 74842.0,
#  'Pastry & Cooking (Without Net)': 6118.0,
#  'i am EB': 1.0,
#  'Stocks: Realtime Quotes Charts': 16808.0,
#  'Acupuncture Assistant': 492.0,
#  'magicApp Calling & Messaging': 207712.0,
#  'Results for FL Lottery': 146.0,
#  'Roland DG Mobile Panel': 27.0,
#  'Dr. Cares - Pet Rescue 911 🐶': 14432.0,
#  'Hotels.com: Book Hotel Rooms & Find Vacation Deals': 260133.0,
#  'University of Florida': 168.0,
#  'Free DS Emulator': 22896.0,
#  'Awake Dating': 2.0,
#  'Florida 511': 148.0,
#  'Cytus II': 16851.0,
#  '420 BZ Budeze Delivery': 2.0,
#  'DW Learn German - A1, A2, B1 and placement test': 902.0,
#  'Clean My Android': 101163.0,
#  'FrostWire: Torrent Downloader & Music Player': 253207.0,
#  'Flight & Hotel Booking App - ixigo': 45562.0,
#  'AJ+ Beta': 0.0,
#  'CV maker for Job Applications and Resume Maker': 75.0,
#  'Ay Vamos - PJ. Balvin - Piano': 0.0,
#  'Four In A Line': 22191.0,
#  'Account Class-12 Solutions (D K Goel) Vol-1': 708.0,
#  'Traffic Sniper Counter Attack': 5339.0,
#  'AJ Cam': 44.0,
#  'SportsManias Fantasy Team News': 4057.0,
#  'NFL': 459797.0,
#  'Je Parle ANGLAIS - Apprendre l’anglais Audio cours': 499.0,
#  'Online Girls Chat Group': 5.0,
#  'The Church at CW': 2.0,
#  'Travis CU': 207.0,
#  'TN Electricity (TNEB)': 73.0,
#  'Open in WhatsApp (click to chat)': 12121.0,
#  'FD Fotografia': 2.0,
#  'DB Navigator': 119685.0,
#  'Fitness & Bodybuilding': 95201.0,
#  'CR Family': 10.0,
#  'Sun & Moon AR Locator': 115.0,
#  'VideoShow-Video Editor, Video Maker, Beauty Camera': 4016834.0,
#  'Brain Waves - Binaural Beats': 5038.0,
#  'NDS Emulator - For Android 6': 14002.0,
#  'Ziggo GO': 29690.0,
#  'Neon Blue Gaming Wallpaper&Theme fo Lenovo K8 Note': 7.0,
#  'Heart Surgery Doctor - ER Emergency Game': 2510.0,
#  'What U See': 712.0,
#  'Grand Bat Superhero Flying Assault Rescue Mission': 1094.0,
#  'K-Spapp, the K-Space app': 39.0,
#  'Q Operator': 60.0,
#  'do': 1073.0,
#  'Arizona Trail': 65.0,
#  'Modern Sniper Strike: Best Commando Action 2k18': 164.0,
#  'Graphing Calculator': 12388.0,
#  'Business Calendar Pro': 27135.0,
#  'R Programing Offline Tutorial': 4.0,
#  'TorrDroid - Torrent Downloader': 59632.0,
#  'iScore5 AP Psych': 10.0,
#  'Step Counter - Pedometer Free & Calorie Counter': 117925.0,
#  'Selfie Camera Photo Editor & Filter & Sticker': 187.0,
#  'Sverige Tidningar': 905.0,
#  'DreamWorks Friends': 1042.0,
#  'Flashlight Free w/ compass': 75.0,
#  'BN MALLORCA Radio': 23.0,
#  'FINAL FANTASY BRAVE EXVIUS': 745684.0,
#  'DT-VR': 25.0,
#  'Philips IQon Spectral CT Fundamentals.': 2.0,
#  'SleepyTime: Bedtime Calculator': 19621.0,
#  'Heroes of Dragon Age': 70389.0,
#  'Google Docs': 815974.0,
#  'Restaurant Inspections - FL': 143.0,
#  'Learn Quran with Elif Ba': 3.0,
#  'Google app for Android TV': 66.0,
#  'BM Tahmin: Ücretsiz İddaa Tahminleri': 7.0,
#  'EmuBox - Fast Retro Emulator': 1576.0,
#  'IKO': 167168.0,
#  'Ah Bailar': 10.0,
#  'Whist - Tinnitus Relief': 12.0,
#  'LineStar for FanDuel': 1539.0,
#  'BJ Grand Salon Mobile App': 1.0,
#  'Superheroes, Marvel, DC, Comics, TV, Movies News': 34.0,
#  'FP Opgaver': 9.0,
#  'American Girls Mobile Numbers': 5.0,
#  'Microsoft Edge': 27156.0,
#  'AX Video Player': 569.0,
#  'Loreal - BA Makeup': 8.0,
#  'Dragon B.Z Wallpapers': 0.0,
#  'Virtual Assistant DataBot: Artificial Intelligence': 80927.0,
#  'Driving Cars Simulator Citroen': 3.0,
#  'Music Collector Inventory Organizer UPC Discogs': 155.0,
#  'Basket Manager 2016 Free': 1879.0,
#  'MapQuest: Directions, Maps, GPS & Navigation': 53481.0,
#  'Todoist: To-do lists for task management & errands': 155998.0,
#  'Attack the Light': 19209.0,
#  'DK Online': 21.0,
#  'Photo Mixer': 55427.0,
#  'Farming Simulator 18': 18125.0,
#  'DP Photo Editor': 88.0,
#  'Quran Juz-30 - Mahad al Zahra': 2654.0,
#  'CD View Lite': 2.0,
#  'CK Life': 3.0,
#  'Itau bank': 957973.0,
#  'MCQ CE IT': 22.0,
#  ...}

# %% [markdown]
# In a previous code cell, we found that there are 1,181 cases where an app occurs more than once, so the length of our dictionary (of unique apps) should be equal to the difference between the length of our data set and 1,181.

# %%
#if both of these numbers are equal, we know we have correctly filled our dictionary with non-duplicate apps
print("Number of expected entries in dictionary: ", len(a_body) - len(duplicate_apps))
print("Number of actual entries in dictionary: ", len(reviews_max))
# Out:
# Number of expected entries in dictionary:  9658
# Number of actual entries in dictionary:  9658

# %% [markdown]
# Our outputs match! This means we have correctly filled our dictionary with non-duplicate apps.
#
# Now, it's time to utilize this dictionary to clean our data and remove duplicate apps.

# %%
#although we aren't technically deleting duplicate apps, we are filling a replica dataset with non-duplicate apps
android_clean = []
already_added = []

for element in a_body:
    name = element[0]
    rating = float(element[3])
    
    if (name not in already_added) and (reviews_max[name] == rating):
        android_clean.append(element)
        already_added.append(name)

data_info("'android_clean'", android_clean)
# Out:
# Number of rows in  'android_clean' data set:  9658
# Number of columns in  'android_clean' data set:  13

# %% [markdown]
# Since we have the same number of rows in our dataset list then we did in our dictionary, we can verify that we have correctly filled our new list with non-duplicate data. Now, it is time for the next step in the data-cleaning process.

# %% [markdown]
# ## Removing Non-English Apps

# %% [markdown]
# Many apps in our dataset are not directed toward English audiences and they contain foreign names and texts. Since we are not interested in analyzing non-English apps, we need to remove them from our dataset. In order to successfully clean our data from non-English apps, we first need to identify the apps that do not contain English text.
#
# We can use ASCII values to determine whether or not an app name contains non-english text. All characters that are specific to English texts are encoded using the ASCII standard. Each ASCII character has a corresponding number between 0 and 127 associated with it, and we can take advantage of that to build a function that checks an app name and tells us whether it contains non-ASCII characters.

# %%
#defining a function that detects whether a string contains english characters or not
def is_english(string):
    for char in string:
        if ord(char) > 127:
            return False
    return True

#sample app names
print(is_english("Instagram"))
print(is_english("\n謎解き＆ブロックパズル"))
print(is_english("Go™"))
print(is_english("Instachat 😜"))
# Out:
# True
# False
# False
# False

# %% [markdown]
# Although our function works fine, it does not pickup on specific characters such as the TM symbol ( ™ ), and emojis ( 😜 ) because they fall outside the ASCII range. It is not the best idea to use this function to remove non-English apps because it may remove apps relevant to our analysis.
#
# In order to improve this function, we can try removing apps that contain three or more non-ASCII characters:

# %%
#improved is_english function
def is_english(string):
    count = 0
    for char in string:
        if ord(char) > 127:
            count += 1  
    if (count > 2):
        return False
    return True

#sample app names
print(is_english("Instagram"))
print(is_english("\n謎解き＆ブロックパズル"))
print(is_english("Go™"))
print(is_english("Instachat 😜"))
# Out:
# True
# False
# True
# True

# %% [markdown]
# By adding a limit to the amount of non-ASCII characters allowed, we can filter out non-English apps more effectively. Although very few non-English apps might get past our filter, this seems good enough for our analysis — we shouldn't spend too much time on optimization at this point.
#
# Below, we use this function to filter out non-English apps from both our android and iOS datasets:

# %%
android_english = []
ios_english = []

#prints the quantity of rows in each dataset prior to filtering
print("Number of rows in Android data set before filtering: ", len(android_clean))
print("Number of rows in iOS data set before filtering: ", len(ios_body))
print('\n----------------------------------------------')

#filtering the android dataset
for element in android_clean:
    name = element[0]
    if (is_english(name)):
        android_english.append(element)

#filtering the iOS dataset
for element in ios_body:
    name = element[1] #the name of an app is at index 1 for IOS dataset
    if (is_english(name)):
        ios_english.append(element)

data_info('Android', android_english)
data_info('iOS', ios_english)
# Out:
# Number of rows in Android data set before filtering:  9658
# Number of rows in iOS data set before filtering:  7197
#
# ----------------------------------------------
#
# Number of rows in  Android data set:  9596
# Number of columns in  Android data set:  13
#
# Number of rows in  iOS data set:  6155
# Number of columns in  iOS data set:  16

# %% [markdown]
# As we can see from this output, we have filtered out approximately 62 foreign app entries from our Android dataset, and approximately 1,042 foreign app entries from our iOS dataset.

# %% [markdown]
# ## Isolating Free Apps

# %% [markdown]
# As we mentioned in the introduction, we only build apps that are free to download and install, and our main source of revenue consists of in-app ads. Our data sets contain both free and non-free apps; we'll need to isolate only the free apps for our analysis.

# %%
print(a_header,'\n')
print(ios_header)
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
#
# ['id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']

# %% [markdown]
# From this output, we can see that:
#     - the price column for android lies at index 7
#     - the price column for iOS lies at index 4
#
# We can use this information to filter out priced apps:

# %%
android_free = []
ios_free = []

#filtering out priced Android apps
for element in android_english:
    price_type = element[6] #adding type constraint for more accurate data
    price = element[7]
    
    if (price_type == 'Free') and (price == '0'): 
        android_free.append(element)

#filtering out priced iOS apps
for element in ios_english:
    price = element[4]
    
    if (price == '0.0'):
        ios_free.append(element)
        
print(len(android_free))
print(len(ios_free))
# Out:
# 8846
# 3203

# %% [markdown]
# After filtering out the priced apps, our dataset for Android now consists of 8846 free apps and our dataset for iOS now consists of 3203 free apps; this should be enough for our analysis.

# %% [markdown]
# ## Most Common Apps By Genre

# %% [markdown]
# ### Part One
#
# Creating the functions to use for our analysis:

# %%
from collections import OrderedDict #used to sort the dictionaries
import pprint #used to print each element of the sorted dictionary on a new line for a clearer output

def freq_table(dataset, index):
    freq_table = {}
    freq_percentage = {}
    total = 0
    
    for element in dataset:
        column = element[index]
        if column in freq_table:
            freq_table[column] += 1 
        else:
            freq_table[column] = 1  
        total += 1
        
    for element in freq_table:
        count = freq_table[element]
        freq_percentage[element] = round(count/total * 100, 4)
        
    return freq_table, freq_percentage


#type 0 to return a frequency table, type 1 to return a frequency percentage table
def get_table(dataset, index, table_type, a_z): 
    
    table_tuple = freq_table(dataset, index)
    table = table_tuple[table_type]
    
    #a_z = true if you wish to return desired table in alphabetical order
    if (a_z):
        table_az = OrderedDict(sorted(table.items()))
        alphabetical = pprint.pprint(table_az)
        return alphabetical
    
    #else, it will return from highest to lowest value
    else:
        table_descending = OrderedDict(sorted(table.items(), reverse = True, key = lambda t: t[1]))
        descending = pprint.pprint(table_descending)
        return descending

# %% [markdown]
# This algorithm get_table() gives us a lot of flexibility in our analysis because if we wanted to, we could visualize this data in a variety of different ways. With this algorithm we can see the frequency table (by count or percentage) of any dataset, by any column pertaining to that dataset, either by alphatebical or key-value descending order.

# %% [markdown]
# ### Part Two
#
# Examining our outputs:

# %%
print("Market Share of Free, English iOS Apps by Category: \n")
get_table(ios_free, -5, 1, False) #category for ios = index 11 (or -5)

print("\n\nMarket Share of Free, English Android Apps by Category: \n")
get_table(android_free, 1, 1, False) #category for android = index 1
# Out:
# Market Share of Free, English iOS Apps by Category:
#
# {'Games': 58.2579,
#  'Entertainment': 7.8364,
#  'Photo & Video': 4.9953,
#  'Education': 3.684,
#  'Social Networking': 3.3094,
#  'Shopping': 2.5913,
#  'Utilities': 2.4664,
#  'Sports': 2.1542,
#  'Music': 2.0606,
#  'Health & Fitness': 2.0293,
#  'Productivity': 1.7484,
#  'Lifestyle': 1.561,
#  'News': 1.3425,
#  'Travel': 1.2488,
#  'Finance': 1.0927,
#  'Weather': 0.8742,
#  'Food & Drink': 0.8117,
#  'Reference': 0.5308,
#  'Business': 0.5308,
#  'Book': 0.3746,
#  'Medical': 0.1873,
#  'Navigation': 0.1873,
#  'Catalogs': 0.1249}
#
#
# Market Share of Free, English Android Apps by Category:
#
# {'FAMILY': 19.2516,
#  'GAME': 9.4845,
#  'TOOLS': 8.4558,
#  'BUSINESS': 4.5896,
#  'PRODUCTIVITY': 3.9001,
#  'LIFESTYLE': 3.8888,
#  'FINANCE': 3.7079,
#  'MEDICAL': 3.5496,
#  'SPORTS': 3.414,
#  'PERSONALIZATION': 3.3235,
#  'COMMUNICATION': 3.2444,
#  'HEALTH_AND_FITNESS': 3.0748,
#  'PHOTOGRAPHY': 2.9505,
#  'NEWS_AND_MAGAZINES': 2.8035,
#  'SOCIAL': 2.6679,
#  'TRAVEL_AND_LOCAL': 2.34,
#  'SHOPPING': 2.2496,
#  'BOOKS_AND_REFERENCE': 2.1366,
#  'DATING': 1.8652,
#  'VIDEO_PLAYERS': 1.7861,
#  'MAPS_AND_NAVIGATION': 1.3905,
#  'FOOD_AND_DRINK': 1.2435,
#  'EDUCATION': 1.1305,
#  'AUTO_AND_VEHICLES': 0.927,
#  'LIBRARIES_AND_DEMO': 0.927,
#  'ENTERTAINMENT': 0.8818,
#  'HOUSE_AND_HOME': 0.8026,
#  'WEATHER': 0.7913,
#  'EVENTS': 0.7122,
#  'PARENTING': 0.6557,
#  'ART_AND_DESIGN': 0.6444,
#  'COMICS': 0.6104,
#  'BEAUTY': 0.5991}

# %% [markdown]
# If we analyze the market make-up of the App Store and Google Play Store by app category, we can see some vast differences. The 'Games' app category consists of over half of the free, English apps within the App Store (58.26%), while the same category in the Google Play Store is far less common (9.48%).
#
# It seems as though the majority of the apps on the Apple Store are designed for fun (games, entertainment, photo and video, etc.), while the apps on the Google Play Store have a more balanced selection of practical purposes (family, tools, business, productivity).
#
# One discrepency to notice is that the App Store does not have 'Family' category. This category makes up the majority of apps on the Google Play Store (19.25%). It could be possible that kid-friendly games on the Google Play Store have been labeled as 'Family' rather than 'Games'. This possibility could explain the vast disparity between the amount of apps with the 'Games' category in the App Store compared to the amount of apps with this same category in the Google Play Store.
#
# Another factor to keep into account is that just because the "fun" apps are the majority within the App Store, this does not mean they are the most popular. The amount of apps offered does not directly translate into the demand for these type of apps.

# %%
print("\n\nMarket Share of Free, English Android Apps by Genre: \n")
get_table(android_free, 9, 1, False) #Genre for android = index 1
# Out:
# Market Share of Free, English Android Apps by Genre:
#
# {'Tools': 8.4445,
#  'Entertainment': 6.0818,
#  'Education': 5.3584,
#  'Business': 4.5896,
#  'Productivity': 3.9001,
#  'Lifestyle': 3.8775,
#  'Finance': 3.7079,
#  'Medical': 3.5496,
#  'Sports': 3.4592,
#  'Personalization': 3.3235,
#  'Communication': 3.2444,
#  'Action': 3.0974,
#  'Health & Fitness': 3.0748,
#  'Photography': 2.9505,
#  'News & Magazines': 2.8035,
#  'Social': 2.6679,
#  'Travel & Local': 2.3287,
#  'Shopping': 2.2496,
#  'Books & Reference': 2.1366,
#  'Simulation': 2.0461,
#  'Dating': 1.8652,
#  'Arcade': 1.8539,
#  'Video Players & Editors': 1.7861,
#  'Casual': 1.7522,
#  'Maps & Navigation': 1.3905,
#  'Food & Drink': 1.2435,
#  'Puzzle': 1.1305,
#  'Racing': 0.9948,
#  'Role Playing': 0.9383,
#  'Libraries & Demo': 0.927,
#  'Auto & Vehicles': 0.927,
#  'Strategy': 0.9044,
#  'House & Home': 0.8026,
#  'Weather': 0.7913,
#  'Events': 0.7122,
#  'Adventure': 0.667,
#  'Beauty': 0.5991,
#  'Art & Design': 0.5991,
#  'Comics': 0.5991,
#  'Parenting': 0.4974,
#  'Card': 0.4409,
#  'Trivia': 0.4183,
#  'Casino': 0.4183,
#  'Educational;Education': 0.3957,
#  'Board': 0.3844,
#  'Educational': 0.373,
#  'Education;Education': 0.3391,
#  'Word': 0.26,
#  'Casual;Pretend Play': 0.2374,
#  'Music': 0.2035,
#  'Puzzle;Brain Games': 0.1696,
#  'Entertainment;Music & Video': 0.1696,
#  'Racing;Action & Adventure': 0.1696,
#  'Casual;Action & Adventure': 0.1357,
#  'Casual;Brain Games': 0.1357,
#  'Arcade;Action & Adventure': 0.1243,
#  'Action;Action & Adventure': 0.1017,
#  'Educational;Pretend Play': 0.0904,
#  'Entertainment;Brain Games': 0.0791,
#  'Board;Brain Games': 0.0791,
#  'Simulation;Action & Adventure': 0.0791,
#  'Parenting;Education': 0.0791,
#  'Art & Design;Creativity': 0.0678,
#  'Parenting;Music & Video': 0.0678,
#  'Casual;Creativity': 0.0678,
#  'Educational;Brain Games': 0.0678,
#  'Education;Pretend Play': 0.0565,
#  'Education;Creativity': 0.0452,
#  'Role Playing;Pretend Play': 0.0452,
#  'Entertainment;Action & Adventure': 0.0339,
#  'Role Playing;Action & Adventure': 0.0339,
#  'Adventure;Action & Adventure': 0.0339,
#  'Educational;Action & Adventure': 0.0339,
#  'Education;Brain Games': 0.0339,
#  'Educational;Creativity': 0.0339,
#  'Entertainment;Creativity': 0.0339,
#  'Puzzle;Action & Adventure': 0.0339,
#  'Education;Music & Video': 0.0339,
#  'Education;Action & Adventure': 0.0339,
#  'Simulation;Pretend Play': 0.0226,
#  'Board;Action & Adventure': 0.0226,
#  'Entertainment;Pretend Play': 0.0226,
#  'Sports;Action & Adventure': 0.0226,
#  'Puzzle;Creativity': 0.0226,
#  'Casual;Education': 0.0226,
#  'Music;Music & Video': 0.0226,
#  'Video Players & Editors;Music & Video': 0.0226,
#  'Strategy;Action & Adventure': 0.0113,
#  'Communication;Creativity': 0.0113,
#  'Health & Fitness;Education': 0.0113,
#  'Parenting;Brain Games': 0.0113,
#  'Entertainment;Education': 0.0113,
#  'Music & Audio;Music & Video': 0.0113,
#  'Art & Design;Action & Adventure': 0.0113,
#  'Simulation;Education': 0.0113,
#  'Card;Brain Games': 0.0113,
#  'Card;Action & Adventure': 0.0113,
#  'Tools;Education': 0.0113,
#  'Comics;Creativity': 0.0113,
#  'Lifestyle;Pretend Play': 0.0113,
#  'Casual;Music & Video': 0.0113,
#  'Strategy;Creativity': 0.0113,
#  'Arcade;Pretend Play': 0.0113,
#  'Role Playing;Brain Games': 0.0113,
#  'Racing;Pretend Play': 0.0113,
#  'Lifestyle;Education': 0.0113,
#  'Travel & Local;Action & Adventure': 0.0113,
#  'Health & Fitness;Action & Adventure': 0.0113,
#  'Trivia;Education': 0.0113,
#  'Art & Design;Pretend Play': 0.0113,
#  'Strategy;Education': 0.0113,
#  'Adventure;Education': 0.0113,
#  'Puzzle;Education': 0.0113,
#  'Books & Reference;Education': 0.0113}

# %% [markdown]
# The difference between the 'Category' of android apps and the 'Genre' of android apps is not entirely clear, but the majority of apps by 'Genre' also appear to consist of practical uses (tools, business, productivity, lifestyle).
#
# The 'Genre' column has numerous rows, many of which are very specific. Since we are only looking for the bigger picture at the moment, it would be best to stick to the 'Category' column for our analysis.
#
# Now, we'd like to get an idea about the kind of apps that have the most users.

# %% [markdown]
# ## Most Popular Apps By Genre on the App Store

# %% [markdown]
# ### Part One
#
# One way to find out what genres are the most popular is to calculate the average number of installs for each app genre. For the Google Play data set, we can find this information in the Installs column, but for the App Store data set this information is missing.
#
# As an alternative, we can use the total number of user ratings to find which apps are most popular in the App Store.

# %%
ios_genres = freq_table(ios_free, -5) #returns a tuple of dictionaries
ios_genres = ios_genres[0] #sets ios_genres equal to the freq_table dictionary

#need to iterate through nested-for loop to find # of user ratings
for name in ios_genres:
    genre_reviews = {}
    num_reviews = 0
    total = 0
    
    for app in ios_english:
        genre = app[-5] #index -5 = genre
        user_rating = float(app[5]) #index 5 = total user rating
        if (name == genre):
            num_reviews += user_rating
            total += 1
    
    avg_rating = num_reviews/total
    genre_reviews[name] = round(avg_rating, 2)   
    print(genre_reviews)
# Out:
# {'Entertainment': 8920.81}
# {'Shopping': 26938.96}
# {'News': 17283.54}
# {'Finance': 23840.06}
# {'Music': 29047.11}
# {'Catalogs': 3465.0}
# {'Food & Drink': 19934.39}
# {'Lifestyle': 9021.5}
# {'Business': 5149.32}
# {'Utilities': 8002.3}
# {'Weather': 23145.25}
# {'Health & Fitness': 10868.02}
# {'Education': 2478.21}
# {'Games': 15641.67}
# {'Social Networking': 60253.85}
# {'Medical': 648.95}
# {'Photo & Video': 14688.72}
# {'Sports': 15350.91}
# {'Book': 10750.11}
# {'Navigation': 19370.82}
# {'Reference': 28096.22}
# {'Productivity': 8508.09}
# {'Travel': 19351.44}

# %% [markdown]
# From a quick glance through this output, we can see that the 'Social Networking' genre generated the highest average number of user reviews with an average of over 60,000 reviews.
#
# Upon further inspection, we can see which apps are the most popular within this genre:

# %%
#there is a large quantity of 'Social Net.' apps so this counter limits the output to just the 5 most popular ones
count = 0  

for app in ios_free:
    name = app[1]
    user_rating = float(app[5])
    
    if (count < 5):
        print(name, ':', user_rating)
        count += 1
# Out:
# Facebook : 2974676.0
# Instagram : 2161558.0
# Clash of Clans : 2130805.0
# Temple Run : 1724546.0
# Pandora - Music & Radio : 1126879.0

# %% [markdown]
# With dominant apps like Facebook with nearly three million user reviews, the average number of 'Social Networking' app reviews is skewed. This occurance also applies to music apps where big players like Spotify and Soundcloud heavily influence the average number.
#
# Our aim is to find popular genres, but navigation, social networking or music apps might seem more popular than they really are. The average number of ratings seem to be skewed by very few apps which have hundreds of thousands of user ratings, while other apps may struggle to reach a few thousand.
#
# To further illustrate this, Reference apps have 28,096.22 user ratings on average, but it's actually the Bible and Dictionary.com which skew up the average rating:

# %%
ratings = []

for app in ios_free:
    name = app[1]
    genre = app[-5]
    user_rating = float(app[5])
    
    if  (genre == 'Reference'):
        ratings.append(user_rating)
        
        #Printing all of the free, iOS apps with a 'Reference' genre and printing their quantity of user ratings
        print(name, ':', user_rating)
# Out:
# Bible : 985920.0
# Dictionary.com Dictionary & Thesaurus : 200047.0
# Dictionary.com Dictionary & Thesaurus for iPad : 54175.0
# Google Translate : 26786.0
# Muslim Pro: Ramadan 2017 Prayer Times, Azan, Quran : 18418.0
# New Furniture Mods - Pocket Wiki & Game Tools for Minecraft PC Edition : 17588.0
# Merriam-Webster Dictionary : 16849.0
# Night Sky : 12122.0
# City Maps for Minecraft PE - The Best Maps for Minecraft Pocket Edition (MCPE) : 8535.0
# LUCKY BLOCK MOD ™ for Minecraft PC Edition - The Best Pocket Wiki & Mods Installer Tools : 4693.0
# GUNS MODS for Minecraft PC Edition - Mods Tools : 1497.0
# Guides for Pokémon GO - Pokemon GO News and Cheats : 826.0
# WWDC : 762.0
# Horror Maps for Minecraft PE - Download The Scariest Maps for Minecraft Pocket Edition (MCPE) Free : 718.0
# VPN Express : 14.0
# Real Bike Traffic Rider Virtual Reality Glasses : 8.0
# Jishokun-Japanese English Dictionary & Translator : 0.0

# %% [markdown]
# Since the average number of user reviews is skewed for most genres, it would be better to look at the median value instead; many averages have a skewed distribution from 1 or 2 popular apps heavily influencing the average.
#
# Let's take a look at the median number of reviews for each genre:

# %%
import statistics
def get_median_ios(genre_name):
    ratings = []

    for app in ios_free:
        genre = app[-5]
        user_rating = float(app[5])
    
        if  (genre == genre_name):
            ratings.append(user_rating)       
        else:
            continue
    
        median = statistics.median(ratings)
    return median

for app in ios_genres:
    print(app, ': ', get_median_ios(str(app)))
# Out:
# Entertainment :  1205.0
# Shopping :  6408.0
# News :  373.0
# Finance :  2207.0
# Music :  3850.0
# Catalogs :  1229.0
# Food & Drink :  1490.5
# Lifestyle :  1183.0
# Business :  1150.0
# Utilities :  1341.0
# Weather :  289.0
# Health & Fitness :  2459.0
# Education :  606.5
# Games :  913.5
# Social Networking :  4199.0
# Medical :  566.5
# Photo & Video :  2206.0
# Sports :  1628.0
# Book :  665.0
# Navigation :  8196.5
# Reference :  8535.0
# Productivity :  8737.5
# Travel :  798.5

# %% [markdown]
# This is a much better representation of the most popular apps by genre within the iOS App Store... we see that with Reference, Navigation, and Productivity having the highest medians of user-reviews, these genres could be very promising for a new app coming to market.
#
# If we research our potential competition and create a plan to develop a clear competitive advantage, we could have a good opportunity to create a popular iOS app within these genres. The more popular the app becomes, the more revenue we will have coming in (due to in-app advertisements).

# %% [markdown]
# ## Most Popular Apps by Genre on Google Play

# %% [markdown]
# For the Google Play market, we actually have data about the number of installs, so we should be able to get a clearer picture about genre popularity. However, the install numbers don't seem precise enough — we can see that most values are open-ended (100+, 1,000+, 5,000+, etc.):

# %%
get_table(android_free, 5, 1, False) #installs column for android = index 5
# Out:
# {'1,000,000+': 15.7698,
#  '100,000+': 11.5532,
#  '10,000,000+': 10.5245,
#  '10,000+': 10.208,
#  '1,000+': 8.3993,
#  '100+': 6.9297,
#  '5,000,000+': 6.8279,
#  '500,000+': 5.5618,
#  '50,000+': 4.7705,
#  '5,000+': 4.4879,
#  '10+': 3.5383,
#  '500+': 3.2444,
#  '50,000,000+': 2.2835,
#  '100,000,000+': 2.1366,
#  '50+': 1.9218,
#  '5+': 0.7913,
#  '1+': 0.5087,
#  '500,000,000+': 0.2713,
#  '1,000,000,000+': 0.2261,
#  '0+': 0.0452}

# %% [markdown]
# This data is not very precise. For example, we don't know whether an app with 100,000+ installs has 150,000 installs or 350,000. However, we don't need very precise data for our purposes — we only want to get an idea which app genres attract the most users, and we don't need perfect precision with respect to the number of users. Thus, we are going to leave these numbers as they are.
#
# To perform computations, however, we'll need to convert each install number to float — this means that we need to remove the commas and the plus characters, otherwise the conversion will fail and raise an error. In the loop below, we will make this conversion and we will also calculate the average number of installs by genre:

# %%
categories_dict = freq_table(android_free, 1)
categories_dict = categories_dict[1]

avg_max = []

for category in categories_dict:
    total_installs = 0
    num_of_categories = 0
    
    for app in android_free:
        app_category = app[1]
        
        if (app_category == category):            
            installs = app[5]
            installs = installs.replace(',', '')
            installs = installs.replace('+', '')
            total_installs += float(installs)
            num_of_categories += 1
            
    average_installs = total_installs / num_of_categories
    avg_max.append(average_installs)
    print(category, ': ', average_installs)

print('\nGreatest average of installs: ', max(avg_max))
# Out:
# EDUCATION :  1768500.0
# PHOTOGRAPHY :  17840110.40229885
# SHOPPING :  7036877.311557789
# SOCIAL :  23253652.127118643
# FAMILY :  5183203.576042279
# ENTERTAINMENT :  9146923.076923076
# AUTO_AND_VEHICLES :  647317.8170731707
# ART_AND_DESIGN :  1986335.0877192982
# PRODUCTIVITY :  16772838.591304347
# LIFESTYLE :  1446158.2238372094
# TOOLS :  10830251.970588235
# LIBRARIES_AND_DEMO :  634095.243902439
# DATING :  854028.8303030303
# NEWS_AND_MAGAZINES :  9549178.467741935
# MEDICAL :  123064.7898089172
# FOOD_AND_DRINK :  1924897.7363636363
# EVENTS :  253542.22222222222
# FINANCE :  1387692.475609756
# HEALTH_AND_FITNESS :  4167457.3602941176
# TRAVEL_AND_LOCAL :  13984077.710144928
# SPORTS :  4288677.758278145
# WEATHER :  5145550.285714285
# PERSONALIZATION :  5201482.6122448975
# VIDEO_PLAYERS :  24790074.17721519
# MAPS_AND_NAVIGATION :  4049274.6341463416
# HOUSE_AND_HOME :  1360598.042253521
# COMICS :  832613.8888888889
# PARENTING :  542603.6206896552
# BUSINESS :  1704192.3399014778
# COMMUNICATION :  38459603.452961676
# GAME :  12856691.835518474
# BOOKS_AND_REFERENCE :  8814199.78835979
# BEAUTY :  513151.88679245283
#
# Greatest average of installs:  38459603.452961676

# %% [markdown]
# On average, communication apps have the most installs: 38,459,603. This number is heavily skewed up by a few apps that have over one billion installs (WhatsApp, Facebook Messenger, Skype, Google Chrome, Gmail, and Hangouts), and a few others with over 100 and 500 million installs:

# %%
for app in android_free:
    name = app[0]
    category = app[1]
    installs = app[5]
    
    if (category == 'COMMUNICATION' and (installs == '100,000,000+' or 
                                         installs == '500,000,000+' or 
                                         installs == '1,000,000,000+')):
        
        print(name, ': ', installs)
# Out:
# Messenger – Text and Video Chat for Free :  1,000,000,000+
# Gmail :  1,000,000,000+
# imo beta free calls and text :  100,000,000+
# imo free video calls and chat :  500,000,000+
# Android Messages :  100,000,000+
# Google Duo - High Quality Video Calls :  500,000,000+
# UC Browser - Fast Download Private & Secure :  500,000,000+
# Skype - free IM & video calls :  1,000,000,000+
# Who :  100,000,000+
# GO SMS Pro - Messenger, Free Themes, Emoji :  100,000,000+
# WhatsApp Messenger :  1,000,000,000+
# Google Chrome: Fast & Secure :  1,000,000,000+
# Firefox Browser fast & private :  100,000,000+
# Messenger Lite: Free Calls & Messages :  100,000,000+
# LINE: Free Calls & Messages :  500,000,000+
# Hangouts :  1,000,000,000+
# Kik :  100,000,000+
# KakaoTalk: Free Calls & Text :  100,000,000+
# Opera Mini - fast web browser :  100,000,000+
# Opera Browser: Fast and Secure :  100,000,000+
# Telegram :  100,000,000+
# Truecaller: Caller ID, SMS spam blocking & Dialer :  100,000,000+
# UC Browser Mini -Tiny Fast Private & Secure :  100,000,000+
# Viber Messenger :  500,000,000+
# WeChat :  100,000,000+
# Yahoo Mail – Stay Organized :  100,000,000+
# BBM - Free Calls & Messages :  100,000,000+

# %% [markdown]
# If we removed all the communication apps that have over 100 million installs, the average would be reduced roughly ten times:

# %%
under_hundred_million = []
average_installs = 0

for app in android_free:
    category = app[1]
    installs = app[5].replace('+', '')
    installs = installs.replace(',', '')
    installs = float(installs)
        
    if (category == 'COMMUNICATION') and (installs < 100000000.0):
        under_hundred_million.append(installs)

average_installs = sum(under_hundred_million)/len(under_hundred_million)
print('\nAverage Google Play Store app installs for the \'Communication\' category: ', round(average_installs, 2))
# Out:
# Average Google Play Store app installs for the 'Communication' category:  3607331.5

# %% [markdown]
# This pattern also holds true for the video players category. This category is dominated by apps like Youtube, Google Play Movies & TV, and MX Player. The pattern is repeated for social apps (Facebook, Instagram, Google+, etc.), and productivity apps (Microsoft Word, Dropbox, Google Calendar, etc.).
#
# These giants may cause the genres to seem more popular than they truly are. Additionally, it would be difficult to compete with them since they are already dominating the market. For these reasons, we should shift our focus to alternative genres.
#
# The books and reference genre looks fairly popular, with an average number of approximately 8,814,200 installs. Since we found this genre to have potential in the App Store, it could be a good idea to explore this genre in more depth for the Google Play Store:

# %%
for app in android_free:
    name = app[0]
    category = app[1]
    installs = app[5]
    
    if (category == 'BOOKS_AND_REFERENCE'):
        print(name, ': ', installs)
# Out:
# E-Book Read - Read Book for free :  50,000+
# Download free book with green book :  100,000+
# Wikipedia :  10,000,000+
# Cool Reader :  10,000,000+
# Free Panda Radio Music :  100,000+
# Book store :  1,000,000+
# FBReader: Favorite Book Reader :  10,000,000+
# English Grammar Complete Handbook :  500,000+
# Free Books - Spirit Fanfiction and Stories :  1,000,000+
# Google Play Books :  1,000,000,000+
# AlReader -any text book reader :  5,000,000+
# Offline English Dictionary :  100,000+
# Offline: English to Tagalog Dictionary :  500,000+
# FamilySearch Tree :  1,000,000+
# Cloud of Books :  1,000,000+
# Recipes of Prophetic Medicine for free :  500,000+
# ReadEra – free ebook reader :  1,000,000+
# Anonymous caller detection :  10,000+
# Ebook Reader :  5,000,000+
# Litnet - E-books :  100,000+
# Read books online :  5,000,000+
# English to Urdu Dictionary :  500,000+
# eBoox: book reader fb2 epub zip :  1,000,000+
# English Persian Dictionary :  500,000+
# Flybook :  500,000+
# All Maths Formulas :  1,000,000+
# Ancestry :  5,000,000+
# HTC Help :  10,000,000+
# English translation from Bengali :  100,000+
# Pdf Book Download - Read Pdf Book :  100,000+
# Free Book Reader :  100,000+
# eBoox new: Reader for fb2 epub zip books :  50,000+
# Only 30 days in English, the guideline is guaranteed :  500,000+
# Moon+ Reader :  10,000,000+
# SH-02J Owner's Manual (Android 8.0) :  50,000+
# English-Myanmar Dictionary :  1,000,000+
# Golden Dictionary (EN-AR) :  1,000,000+
# All Language Translator Free :  1,000,000+
# Azpen eReader :  500,000+
# URBANO V 02 instruction manual :  100,000+
# Bible :  100,000,000+
# C Programs and Reference :  50,000+
# C Offline Tutorial :  1,000+
# C Programs Handbook :  50,000+
# Amazon Kindle :  100,000,000+
# Aab e Hayat Full Novel :  100,000+
# Aldiko Book Reader :  10,000,000+
# Google I/O 2018 :  500,000+
# R Language Reference Guide :  10,000+
# Learn R Programming Full :  5,000+
# R Programing Offline Tutorial :  1,000+
# Guide for R Programming :  5+
# Learn R Programming :  10+
# R Quick Reference Big Data :  1,000+
# V Made :  100,000+
# Wattpad 📖 Free Books :  100,000,000+
# Dictionary - WordWeb :  5,000,000+
# Guide (for X-MEN) :  100,000+
# AC Air condition Troubleshoot,Repair,Maintenance :  5,000+
# AE Bulletins :  1,000+
# Ae Allah na Dai (Rasa) :  10,000+
# 50000 Free eBooks & Free AudioBooks :  5,000,000+
# Ag PhD Field Guide :  10,000+
# Ag PhD Deficiencies :  10,000+
# Ag PhD Planting Population Calculator :  1,000+
# Ag PhD Soybean Diseases :  1,000+
# Fertilizer Removal By Crop :  50,000+
# A-J Media Vault :  50+
# Al-Quran (Free) :  10,000,000+
# Al Quran (Tafsir & by Word) :  500,000+
# Al Quran Indonesia :  10,000,000+
# Al'Quran Bahasa Indonesia :  10,000,000+
# Al Quran Al karim :  1,000,000+
# Al-Muhaffiz :  50,000+
# Al Quran : EAlim - Translations & MP3 Offline :  5,000,000+
# Al-Quran 30 Juz free copies :  500,000+
# Koran Read &MP3 30 Juz Offline :  1,000,000+
# Hafizi Quran 15 lines per page :  1,000,000+
# Quran for Android :  10,000,000+
# Surah Al-Waqiah :  100,000+
# Hisnul Al Muslim - Hisn Invocations & Adhkaar :  100,000+
# Satellite AR :  1,000,000+
# Audiobooks from Audible :  100,000,000+
# Kinot & Eichah for Tisha B'Av :  10,000+
# AW Tozer Devotionals - Daily :  5,000+
# Tozer Devotional -Series 1 :  1,000+
# The Pursuit of God :  1,000+
# AY Sing :  5,000+
# Ay Hasnain k Nana Milad Naat :  10,000+
# Ay Mohabbat Teri Khatir Novel :  10,000+
# Arizona Statutes, ARS (AZ Law) :  1,000+
# Oxford A-Z of English Usage :  1,000,000+
# BD Fishpedia :  1,000+
# BD All Sim Offer :  10,000+
# Youboox - Livres, BD et magazines :  500,000+
# B&H Kids AR :  10,000+
# B y H Niños ES :  5,000+
# Dictionary.com: Find Definitions for English Words :  10,000,000+
# English Dictionary - Offline :  10,000,000+
# Bible KJV :  5,000,000+
# Borneo Bible, BM Bible :  10,000+
# MOD Black for BM :  100+
# BM Box :  1,000+
# Anime Mod for BM :  100+
# NOOK: Read eBooks & Magazines :  10,000,000+
# NOOK Audiobooks :  500,000+
# NOOK App for NOOK Devices :  500,000+
# Browsery by Barnes & Noble :  5,000+
# bp e-store :  1,000+
# Brilliant Quotes: Life, Love, Family & Motivation :  1,000,000+
# BR Ambedkar Biography & Quotes :  10,000+
# BU Alsace :  100+
# Catholic La Bu Zo Kam :  500+
# Khrifa Hla Bu (Solfa) :  10+
# Kristian Hla Bu :  10,000+
# SA HLA BU :  1,000+
# Learn SAP BW :  500+
# Learn SAP BW on HANA :  500+
# CA Laws 2018 (California Laws and Codes) :  5,000+
# Bootable Methods(USB-CD-DVD) :  10,000+
# cloudLibrary :  100,000+
# SDA Collegiate Quarterly :  500+
# Sabbath School :  100,000+
# Cypress College Library :  100+
# Stats Royale for Clash Royale :  1,000,000+
# GATE 21 years CS Papers(2011-2018 Solved) :  50+
# Learn CT Scan Of Head :  5,000+
# Easy Cv maker 2018 :  10,000+
# How to Write CV :  100,000+
# CW Nuclear :  1,000+
# CY Spray nozzle :  10+
# BibleRead En Cy Zh Yue :  5+
# CZ-Help :  5+
# Guide for DB Xenoverse :  10,000+
# Guide for DB Xenoverse 2 :  10,000+
# Guide for IMS DB :  10+
# DC HSEMA :  5,000+
# DC Public Library :  1,000+
# Painting Lulu DC Super Friends :  1,000+
# Dictionary :  10,000,000+
# Fix Error Google Playstore :  1,000+
# D. H. Lawrence Poems FREE :  1,000+
# Bilingual Dictionary Audio App :  5,000+
# DM Screen :  10,000+
# wikiHow: how to do anything :  1,000,000+
# Dr. Doug's Tips :  1,000+
# Bible du Semeur-BDS (French) :  50,000+
# La citadelle du musulman :  50,000+
# DV 2019 Entry Guide :  10,000+
# DV 2019 - EDV Photo & Form :  50,000+
# DV 2018 Winners Guide :  1,000+
# EB Annual Meetings :  1,000+
# EC - AP & Telangana :  5,000+
# TN Patta Citta & EC :  10,000+
# AP Stamps and Registration :  10,000+
# CompactiMa EC pH Calibration :  100+
# EGW Writings 2 :  100,000+
# EGW Writings :  1,000,000+
# Bible with EGW Comments :  100,000+
# My Little Pony AR Guide :  1,000,000+
# SDA Sabbath School Quarterly :  500,000+
# Duaa Ek Ibaadat :  5,000+
# Spanish English Translator :  10,000,000+
# Dictionary - Merriam-Webster :  10,000,000+
# JW Library :  10,000,000+
# Oxford Dictionary of English : Free :  10,000,000+
# English Hindi Dictionary :  10,000,000+
# English to Hindi Dictionary :  5,000,000+
# EP Research Service :  1,000+
# Hymnes et Louanges :  100,000+
# EU Charter :  1,000+
# EU Data Protection :  1,000+
# EU IP Codes :  100+
# EW PDF :  5+
# BakaReader EX :  100,000+
# EZ Quran :  50,000+
# FA Part 1 & 2 Past Papers Solved Free – Offline :  5,000+
# La Fe de Jesus :  1,000+
# La Fe de Jesús :  500+
# Le Fe de Jesus :  500+
# Florida - Pocket Brainbook :  1,000+
# Florida Statutes (FL Code) :  1,000+
# English To Shona Dictionary :  10,000+
# Greek Bible FP (Audio) :  1,000+
# Golden Dictionary (FR-AR) :  500,000+
# Fanfic-FR :  5,000+
# Bulgarian French Dictionary Fr :  10,000+
# Chemin (fr) :  1,000+
# The SCP Foundation DB fr nn5n :  1,000+

# %% [markdown]
# This genre includes a variety of apps: reading ebooks, dictionaries, tutorials, etc. Nevertheless, there's still a small number of extremely popular apps such as Google Play Books, Bible, and Amazon Kindle that skew the average:

# %%
for app in android_free:
    name = app[0]
    category = app[1]
    installs = app[5]
    
    if (category == 'BOOKS_AND_REFERENCE' and (installs == '100,000,000+' or 
                                         installs == '500,000,000+' or 
                                         installs == '1,000,000,000+')):
        
        print(name, ': ', installs)
# Out:
# Google Play Books :  1,000,000,000+
# Bible :  100,000,000+
# Amazon Kindle :  100,000,000+
# Wattpad 📖 Free Books :  100,000,000+
# Audiobooks from Audible :  100,000,000+

# %% [markdown]
# There are only a few very popular apps, however, so this market still shows some potential. Let's analyze the apps with average-popularity to get an idea on the kinds of apps we could realistically develop:

# %%
for app in android_free:
    name = app[0]
    category = app[1]
    installs = app[5].replace('+', '')
    installs = installs.replace(',', '')
    installs = float(installs)
        
    if (category == 'BOOKS_AND_REFERENCE') and (1000000 <= installs <= 100000000.0): #average popularity: 1M to 100M
        print(name, ': ', installs)
# Out:
# Wikipedia :  10000000.0
# Cool Reader :  10000000.0
# Book store :  1000000.0
# FBReader: Favorite Book Reader :  10000000.0
# Free Books - Spirit Fanfiction and Stories :  1000000.0
# AlReader -any text book reader :  5000000.0
# FamilySearch Tree :  1000000.0
# Cloud of Books :  1000000.0
# ReadEra – free ebook reader :  1000000.0
# Ebook Reader :  5000000.0
# Read books online :  5000000.0
# eBoox: book reader fb2 epub zip :  1000000.0
# All Maths Formulas :  1000000.0
# Ancestry :  5000000.0
# HTC Help :  10000000.0
# Moon+ Reader :  10000000.0
# English-Myanmar Dictionary :  1000000.0
# Golden Dictionary (EN-AR) :  1000000.0
# All Language Translator Free :  1000000.0
# Bible :  100000000.0
# Amazon Kindle :  100000000.0
# Aldiko Book Reader :  10000000.0
# Wattpad 📖 Free Books :  100000000.0
# Dictionary - WordWeb :  5000000.0
# 50000 Free eBooks & Free AudioBooks :  5000000.0
# Al-Quran (Free) :  10000000.0
# Al Quran Indonesia :  10000000.0
# Al'Quran Bahasa Indonesia :  10000000.0
# Al Quran Al karim :  1000000.0
# Al Quran : EAlim - Translations & MP3 Offline :  5000000.0
# Koran Read &MP3 30 Juz Offline :  1000000.0
# Hafizi Quran 15 lines per page :  1000000.0
# Quran for Android :  10000000.0
# Satellite AR :  1000000.0
# Audiobooks from Audible :  100000000.0
# Oxford A-Z of English Usage :  1000000.0
# Dictionary.com: Find Definitions for English Words :  10000000.0
# English Dictionary - Offline :  10000000.0
# Bible KJV :  5000000.0
# NOOK: Read eBooks & Magazines :  10000000.0
# Brilliant Quotes: Life, Love, Family & Motivation :  1000000.0
# Stats Royale for Clash Royale :  1000000.0
# Dictionary :  10000000.0
# wikiHow: how to do anything :  1000000.0
# EGW Writings :  1000000.0
# My Little Pony AR Guide :  1000000.0
# Spanish English Translator :  10000000.0
# Dictionary - Merriam-Webster :  10000000.0
# JW Library :  10000000.0
# Oxford Dictionary of English : Free :  10000000.0
# English Hindi Dictionary :  10000000.0
# English to Hindi Dictionary :  5000000.0

# %% [markdown]
# Since this niche seems to be dominated by software for processing, reading ebooks, libraries, and dictionaries, it's probably not the best idea to build similar apps. There would be some significant competition if we build a similar app to the ones already published.
#
# Noticeably, there are quite a few apps built around the book Quran, which suggests that building an app around a popular book can be profitable. It is also worth noticing that reference apps could be very popular as well. The "My Little Pony AR Guide" and "Stats Royale for Clash Royale" apps are perfect examples of this. One underlying theme between these examples is that these apps have benefitted from popular topics (Quran, My Little Pony, Clash Royale).
#
# Nevertheless, it seems that taking a popular book or reference and turning it into an app could be profitable for both the Google Play and the App Store markets.
#
# In order to distinguish ourselves from the competition, we would need to add some special features to our app. For example, this could include daily quotes from the book or reference, included audio of the book or reference, quizzes on the book or reference, a forum for the book or reference, etc.

# %% [markdown]
# ## Conclusions

# %% [markdown]
# In this project, we analyzed data about the App Store and Google Play mobile apps with the goal of recommending an app profile that can be profitable for both markets.
#
# We concluded that taking a popular topic and turning it into a book or reference app could be profitable for both the Google Play and the App Store markets. The markets are already full of libraries, so we need to add some special features to our app. This might include daily quotes from the book or reference, included audio of the book or reference, quizzes on the book or reference, a forum for the book or reference, or any other feature that can provide a competitive advantage over our competitors.
